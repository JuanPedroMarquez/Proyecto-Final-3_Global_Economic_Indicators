# %% [markdown]
# <center><img src="https://images.axios.com/fwS8MUegVxYlXGLmOBDo0UhhQd8=/0x0:1920x1080/1920x1080/filters:no_upscale()/2019/10/14/1571013665367.gif?w=1920" width="900" height="500"></center>
#
# # <center><B><FONT COLOR="#FCB714"> Proyecto de fin de estudios </FONT> <br> Indicadores Económicos Globales </center>

# %% [markdown]
# # <center><B><FONT COLOR="#FCB714"> Variables del Dataset  </center></FONT>

# %% [markdown]
# Variables descriptivas básicas
#
# <FONT COLOR="#FCB714">Country</FONT> : País<br>
# <FONT COLOR="#FCB714">Year</FONT> : Año<br>
# <FONT COLOR="#FCB714">Population</FONT> : Población<br>
# <FONT COLOR="#FCB714">Currency</FONT> : Divisa, moneda local<br>
# <FONT COLOR="#FCB714">Exchange_Rate</FONT> : Tipo de cambio Divisa/USD, obtenido a través del FMI; Divisas que se obtienen con 1 dólar<br>
#
# Actividades económicas
#
# <FONT COLOR="#FCB714">Agriculture_Hunting_Forestry_Fishing</FONT> : Suma del valor de las actividades de  agricultura, caza, silvicultura y pesca; USD<br>
# <FONT COLOR="#FCB714">Construction</FONT> : Valor total de las actividades de construcción; USD<br>
# <FONT COLOR="#FCB714">Manufacturing</FONT> : Valor total las actividades de procesado de productos naturales; USD<br>
# <FONT COLOR="#FCB714">Mining_Manufacturing_Utilities</FONT> : Valor total de las actividades de minería y procesamiento de Materias Primas; USD<br>
# <FONT COLOR="#FCB714">Mining_Utilities</FONT> : Valor total de las actividades de minería y materias primas; USD<br>
# <FONT COLOR="#FCB714">Transport_Storage_Communication</FONT> : Valor total de las actividades de transporte, almacenamiento y comunicaciones; USD<br>
# <FONT COLOR="#FCB714">Wholesale_RetailTrade_Restaurants_Hotels</FONT> : Valor total de las actividades de venta al por mayor, venta al por menor y restauración; USD<br>
# <FONT COLOR="#FCB714">Other_Activities</FONT> : Otras actividades; USD<br>
#
# Indicadores macroeconómicos principales
#
# <FONT COLOR="#FCB714">GNI</FONT> : Gross National Income (Renta Nacional Bruta); USD<br>
# <FONT COLOR="#FCB714">GDP</FONT> : Gross Domestic Product (Producto Interior Bruto); USD<br>
# <FONT COLOR="#FCB714">GNI_pc</FONT> : RNB per cápita; USD<br>
# <FONT COLOR="#FCB714">GNI_pc</FONT> : PIB per cápita; USD<br>
# <FONT COLOR="#FCB714">Consumption</FONT> : Gasto Final en Consumo; USD<br>
# <FONT COLOR="#FCB714">HH_Consumption</FONT> : Gasto en Consumo de los Hogares y empresas no lucrativas al servicio de los hogares; USD<br>
# <FONT COLOR="#FCB714">GCF</FONT> : Gross Capital Formation (Formación Bruta de Capital). Suma de GFCF y Variación de Inventarios; USD<br>
# <FONT COLOR="#FCB714">GFCF</FONT> : Gross Fixed Capital Formation (Formación Bruta de Capital Fijo); USD<br>
# <FONT COLOR="#FCB714">Gov_Consumption</FONT> : Gasto Final en Consumo del Gobierno (educación, sanidad, dependencia, seguridad, medicamentos...); USD<br>
# <FONT COLOR="#FCB714">Exports</FONT> : Suma del valor de las exportaciones de bienes y servicios hacia el exterior; USD<br>
# <FONT COLOR="#FCB714">Imports</FONT> : Suma del valor de las exportaciones de bienes y servicios del exterior; USD<br>
# <FONT COLOR="#FCB714">Total_Value_Added</FONT> : Valor Añadido Total; USD<br>
# <FONT COLOR="#FCB714">Inventory_Changes</FONT> : Variación de Inventarios; USD<br>
#
# Otros indicadores económicos
#
# <FONT COLOR="#FCB714">Continent</FONT> : Continente del país<br>
# <FONT COLOR="#FCB714">GDP_growth</FONT> : Crecimiento del PIB respecto al año anterior; %<br>
# <FONT COLOR="#FCB714">SNE</FONT> : Saldo Neto Externo; USD<br>
# <FONT COLOR="#FCB714">IAC</FONT> : Índice de Apertura Comercial; %<br>
# <FONT COLOR="#FCB714">TCC</FONT> : Tasa de Cobertura Comercial; %<br>
# <FONT COLOR="#FCB714">Exp/GDP</FONT> : Exportaciones en relación con el PIB; %<br>
# <FONT COLOR="#FCB714">IDH</FONT> : Índice de Desarrollo Humano; dato entre 0 y 1<br>
# <FONT COLOR="#FCB714">Unemployment</FONT> : Desempleo total; % de la mano de obra<br>
#
# Códigos [ISIC](https://ilostat.ilo.org/methods/concepts-and-definitions/classification-economic-activities/)

# %% [markdown]
# # <center><B><FONT COLOR="#FCB714"> Índice  </center></FONT>

# %% [markdown]
# 1. <FONT COLOR="#FCB714">Carga de Datos</FONT>
# - Importación de librerías necesarias
# - Lectura de los datos
# 2. <FONT COLOR="#FCB714">Preprocesamiento de Datos</FONT>
# - Limpieza de los datos
# - Tratamiento de datos nulos
# - Corrección de datos erróneos
# - Creación de Variables nuevas
# 3. <FONT COLOR="#FCB714">Exploratory Data Analysis (EDA)</FONT>
# - Análisis Gráfico
# - Análisis Estadístico / Econométrico
# - Técnicas Predictivas
# 4. <FONT COLOR="#FCB714">Conclusiones del Estudio</FONT>
# 5. <FONT COLOR="#FCB714">Fuentes y referencias</FONT>

# %% [markdown]
# # <center><B><FONT COLOR=#FCB714> 1. </FONT> Cargamos los datos  </center></FONT>

# %% [markdown]
# ## <B><FONT COLOR=#FCB714> 1.1 </FONT> Importamos librerías </FONT>

# %% [markdown]
# Primero descargaremos las librerías necesarias para el proyecto, que están indicadas en el requirements con las versiones necesarias
#
# Nota: puede ser recomendable crear un entorno virtual para que las librerías se descarguen mejor

# %%
# Para no mostrar advertencias en el GitHub
import warnings 
warnings.filterwarnings("ignore")

# %%
# %pip install -q -r requirements.txt

# %% [markdown]
# Nota: Crear un venv puede ayudar a que se instalen bien las librerías

# %%
# Para trabajar con datos
import numpy as np
import pandas as pd

# Para visualizar datos con gráficos
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# Para obtener datos de países
import pycountry_convert as pc

# Para hacer contrastes de hipótesis
import scipy.stats as stats
from scipy.stats import ttest_ind, f_oneway

# Para hacer predicciones con series temporales
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.arima.model import ARIMA
from pmdarima.arima import auto_arima
from neuralprophet import NeuralProphet
from sklearn.metrics import mean_squared_error, root_mean_squared_error

# %% [markdown]
# Para no ver más de 15 filas, pero sí hasta 35 columnas

# %%
pd.set_option('display.max_columns', 35)
pd.set_option('display.max_rows', 15)

# %% [markdown]
# ## <B><FONT COLOR=#FCB714> 1.2 </FONT> Leemos los datos* </FONT>

# %% [markdown]
# *Datos obtenidos de [Kaggle](https://www.kaggle.com/datasets/prasad22/global-economy-indicators/data)

# %%
import pandas as pd

# %%
df = pd.read_csv(r"Data\Global_Economy_Indicators.csv")

# %% [markdown]
# Vemos los datos más inmediatos del dataframe

# %%
df.head()
# Out:
#     CountryID        Country    Year    AMA exchange rate   \
# 0            4   Afghanistan     1970             0.044998
# 1            4   Afghanistan     1971             0.044998
# 2            4   Afghanistan     1972             0.044998
# 3            4   Afghanistan     1973             0.044998
# 4            4   Afghanistan     1974             0.044998
#
#     IMF based exchange rate    Population   Currency    Per capita GNI   \
# 0                   0.044998      10752971   Afghani                164
# 1                   0.044998      11015857   Afghani                168
# 2                   0.044998      11286753   Afghani                149
# 3                   0.044998      11575305   Afghani                150
# 4                   0.044998      11869879   Afghani                177
#
#     Agriculture, hunting, forestry, fishing (ISIC A-B)   \
# 0                                       8.699174e+08
# 1                                       9.108281e+08
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10512 entries, 0 to 10511
# Data columns (total 26 columns):
#  #   Column                                                                                      Non-Null Count  Dtype
# ---  ------                                                                                      --------------  -----
#  0    CountryID                                                                                  10512 non-null  int64
#  1    Country                                                                                    10512 non-null  object
#  2    Year                                                                                       10512 non-null  int64
#  3    AMA exchange rate                                                                          10512 non-null  float64
#  4    IMF based exchange rate                                                                    10512 non-null  float64
# ...

# %%
df.describe().T
# Out:
#                                                       count          mean  \
#  CountryID                                          10512.0  4.311166e+02
#  Year                                               10512.0  1.996263e+03
#  AMA exchange rate                                  10512.0  3.573959e+02
#  IMF based exchange rate                            10512.0  3.419846e+02
#  Population                                         10512.0  2.851523e+07
# ...                                                     ...           ...
#  Total Value Added                                  10512.0  1.744795e+11
#  Transport, storage and communication (ISIC I)      10463.0  1.556757e+10
#  Wholesale, retail trade, restaurants and hotel...  10463.0  2.509568e+10
#  Gross National Income(GNI) in USD                  10512.0  1.825260e+11
#  Gross Domestic Product (GDP)                       10512.0  1.828765e+11
#
#                                                              std  \
# ...

# %%
df.columns
# Out:
# Index([' CountryID ', ' Country ', ' Year ', ' AMA exchange rate ',
#        ' IMF based exchange rate ', ' Population ', ' Currency ',
#        ' Per capita GNI ',
#        ' Agriculture, hunting, forestry, fishing (ISIC A-B) ',
#        ' Changes in inventories ', ' Construction (ISIC F) ',
#        ' Exports of goods and services ', ' Final consumption expenditure ',
#        ' General government final consumption expenditure ',
#        ' Gross capital formation ',
#        ' Gross fixed capital formation (including Acquisitions less disposals of valuables) ',
#        ' Household consumption expenditure (including Non-profit institutions serving households) ',
#        ' Imports of goods and services ', ' Manufacturing (ISIC D) ',
#        ' Mining, Manufacturing, Utilities (ISIC C-E) ',
#        ' Other Activities (ISIC J-P) ', ' Total Value Added ',
#        ' Transport, storage and communication (ISIC I) ',
# ...

# %% [markdown]
# # <center><B><FONT COLOR=#FCB714> 2. </FONT> Procesamiento de datos </FONT></center>

# %% [markdown]
# ## <B><FONT COLOR=#FCB714> 2.1 </FONT> Limpieza de los datos </FONT>

# %% [markdown]
# Vemos que los nombres de las columnas tienen espacios de más y paréntesis que queremos quitar. Primero, partimos el texto a partir del paréntesis de apertura y nos quedamos con lo que hay a su izquierda

# %%
df.columns = [col.split('(')[0] for col in df.columns]

# %%
df.columns
# Out:
# Index([' CountryID ', ' Country ', ' Year ', ' AMA exchange rate ',
#        ' IMF based exchange rate ', ' Population ', ' Currency ',
#        ' Per capita GNI ', ' Agriculture, hunting, forestry, fishing ',
#        ' Changes in inventories ', ' Construction ',
#        ' Exports of goods and services ', ' Final consumption expenditure ',
#        ' General government final consumption expenditure ',
#        ' Gross capital formation ', ' Gross fixed capital formation ',
#        ' Household consumption expenditure ',
#        ' Imports of goods and services ', ' Manufacturing ',
#        ' Mining, Manufacturing, Utilities ', ' Other Activities ',
#        ' Total Value Added ', ' Transport, storage and communication ',
#        ' Wholesale, retail trade, restaurants and hotels ',
#        ' Gross National Income', ' Gross Domestic Product '],
#       dtype='object')

# %% [markdown]
# Después, podemos eliminar los espacios del principio y el final del nombre de las variables

# %%
df.columns = df.columns.str.strip()

# %%
df.columns
# Out:
# Index(['CountryID', 'Country', 'Year', 'AMA exchange rate',
#        'IMF based exchange rate', 'Population', 'Currency', 'Per capita GNI',
#        'Agriculture, hunting, forestry, fishing', 'Changes in inventories',
#        'Construction', 'Exports of goods and services',
#        'Final consumption expenditure',
#        'General government final consumption expenditure',
#        'Gross capital formation', 'Gross fixed capital formation',
#        'Household consumption expenditure', 'Imports of goods and services',
#        'Manufacturing', 'Mining, Manufacturing, Utilities', 'Other Activities',
#        'Total Value Added', 'Transport, storage and communication',
#        'Wholesale, retail trade, restaurants and hotels',
#        'Gross National Income', 'Gross Domestic Product'],
#       dtype='object')

# %% [markdown]
# Vamos a convertir la columna Year a un object temporalmente

# %%
df["Year"] = df["Year"].astype(str)

# %% [markdown]
# También tenemos estos espacios en la variable Currency y Country

# %%
df['Currency'] = df['Currency'].str.strip()
df['Country'] = df['Country'].str.strip()

# %% [markdown]
# Eliminamos las variables que no vamos a utilizar

# %%
df.drop(columns=["CountryID","AMA exchange rate"], inplace=True)

# %% [markdown]
# <FONT COLOR="#FCB714">CountryID</FONT> porque no proporciona información más allá de identificar al país, para lo cual nos puede servir la columna Country<br>
# <FONT COLOR="#FCB714">AMA exchange rate</FONT> porque ya tenemos un tipo de cambio que usar, el del Fondo Monetario Internacional

# %%
df.columns
# Out:
# Index(['Country', 'Year', 'IMF based exchange rate', 'Population', 'Currency',
#        'Per capita GNI', 'Agriculture, hunting, forestry, fishing',
#        'Changes in inventories', 'Construction',
#        'Exports of goods and services', 'Final consumption expenditure',
#        'General government final consumption expenditure',
#        'Gross capital formation', 'Gross fixed capital formation',
#        'Household consumption expenditure', 'Imports of goods and services',
#        'Manufacturing', 'Mining, Manufacturing, Utilities', 'Other Activities',
#        'Total Value Added', 'Transport, storage and communication',
#        'Wholesale, retail trade, restaurants and hotels',
#        'Gross National Income', 'Gross Domestic Product'],
#       dtype='object')

# %% [markdown]
# Renombramos las variables, para simplificar su tratamiento y llamado

# %%
df.rename(columns={
    "IMF based exchange rate": "Exchange_Rate",
    "Per capita GNI": "GNI_pc",
    "Agriculture, hunting, forestry, fishing": "Agriculture_Hunting_Forestry_Fishing",
    "Changes in inventories": "Inventory_Changes",
    "Exports of goods and services": "Exports",
    "Imports of goods and services": "Imports",
    "Final consumption expenditure": "Consumption",
    "General government final consumption expenditure": "Gov_Consumption",
    "Gross capital formation": "GCF",
    "Gross fixed capital formation": "GFCF",
    "Household consumption expenditure": "HH_Consumption",
    "Mining, Manufacturing, Utilities": "Mining_Manufacturing_Utilities",
    "Other Activities": "Other_Activities",
    "Total Value Added": "Total_Value_Added",
    "Transport, storage and communication": "Transport_Storage_Communication",
    "Wholesale, retail trade, restaurants and hotels": "Wholesale_RetailTrade_Restaurants_Hotels",
    "Gross National Income": "GNI",
    "Gross Domestic Product": "GDP"
}, inplace=True)

# %%
df.columns
# Out:
# Index(['Country', 'Year', 'Exchange_Rate', 'Population', 'Currency', 'GNI_pc',
#        'Agriculture_Hunting_Forestry_Fishing', 'Inventory_Changes',
#        'Construction', 'Exports', 'Consumption', 'Gov_Consumption', 'GCF',
#        'GFCF', 'HH_Consumption', 'Imports', 'Manufacturing',
#        'Mining_Manufacturing_Utilities', 'Other_Activities',
#        'Total_Value_Added', 'Transport_Storage_Communication',
#        'Wholesale_RetailTrade_Restaurants_Hotels', 'GNI', 'GDP'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10512 entries, 0 to 10511
# Data columns (total 24 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   Country                                   10512 non-null  object
#  1   Year                                      10512 non-null  object
#  2   Exchange_Rate                             10512 non-null  float64
#  3   Population                                10512 non-null  int64
#  4   Currency                                  10512 non-null  object
#  5   GNI_pc                                    10512 non-null  int64
#  6   Agriculture_Hunting_Forestry_Fishing      10391 non-null  float64
#  7   Inventory_Changes                         8671 non-null   float64
#  8   Construction                              10512 non-null  float64
#  9   Exports                                   10491 non-null  float64
# ...

# %% [markdown]
# ## <B><FONT COLOR=#FCB714> 2.2 </FONT> Datos Nulos </FONT>

# %%
df.isnull().sum()/df.shape[0]*100
# Out:
# Country                                     0.000000
# Year                                        0.000000
# Exchange_Rate                               0.000000
# Population                                  0.000000
# Currency                                    0.000000
#                                               ...
# Total_Value_Added                           0.000000
# Transport_Storage_Communication             0.466134
# Wholesale_RetailTrade_Restaurants_Hotels    0.466134
# GNI                                         0.000000
# GDP                                         0.000000
# Length: 24, dtype: float64

# %% [markdown]
# La variable que más nulos tiene es la variación de inventarios, con un 17% de nulos, seguida de las actividades de la agricultura, con un 1%, e inferiores en otros casos.
#
# El origen de estos nulos puede deberse a gran variedad de casuísticas como errores de registro, inexistencia del país en ciertos momentos de la historia y hasta la no elaboración de la estadística *per se*. Además, el tratamiento de los nulos en el ámbito de las Series Temporales merece un tratamiento y reflexión diferentes al de un DataFrame. No podemos sustituir por la media, moda o mediana pues estas variables no contemplan la dimensión del tiempo e incurriríamos en errores debido a la naturaleza y tendencia alcista de nuestras variables (por ejemplo, adjudicarle a un hipotético PIB nulo de España en 1983 el valor del PIB promedio de ese país con el resto de años, generando un pico anómalo en nuestra serie de tiempo).
#
# Por ello, y debido a que la cantidad de nulos tampoco es preocupante (1% o menor), decidimos no dropearlos, pero podría quedar como ejercicio el intentar predecirlos con Machine Learning mediante modelos de Regresión o con modelos de Series Temporales

# %% [markdown]
# ## <B><FONT COLOR=#FCB714> 2.3 </FONT> Corregimos datos negativos </FONT>

# %% [markdown]
# Prestemos atención a la siguiente tabla

# %%
df.describe()
# Out:
#        Exchange_Rate    Population         GNI_pc  \
# count   1.051200e+04  1.051200e+04   10512.000000
# mean    3.419846e+02  2.851523e+07    8965.564593
# std     1.941857e+03  1.141296e+08   17070.205895
# min     4.300000e-14  4.359000e+03      34.000000
# 25%     1.000000e+00  6.330615e+05     730.000000
# 50%     2.761315e+00  5.051556e+06    2316.500000
# 75%     4.806684e+01  1.678862e+07    8965.750000
# max     4.200000e+04  1.425893e+09  234317.000000
#
#        Agriculture_Hunting_Forestry_Fishing  Inventory_Changes  Construction  \
# count                          1.039100e+04       8.671000e+03  1.051200e+04
# mean                           7.793212e+09       1.626543e+09  1.002199e+10
# std                            4.034349e+10       8.932353e+09  4.985596e+10
# min                            2.813900e+04      -1.510000e+11  1.577280e+05
# 25%                            1.304522e+08       4.673545e+05  6.815523e+07
# ...

# %% [markdown]
# Como se puede ver, hay algunos mínimos que no tiene sentido que sean negativos. Excepto Inventory_Changes, que es una variación, ninguna otra variable debería poder adoptar valores negativos. De hecho, lo esperable es que los datos sean estrictamente positivos. Por lo tanto, vamos a aplicar una función de valor absoluto a todos los datos, excepto a Inventory_Changes

# %% [markdown]
# Primero, definimos la lista de variables numéricas como aquellas en las que el tipo de dato sea decimal o entero. Después, aplicamos la función de valor absoluto al dataframe en las columnas numéricas

# %%
numeric_columns = [col for col in df.select_dtypes(include=('float64', 'int64')).columns if col != 'Inventory_Changes']
df[numeric_columns] = df[numeric_columns].abs()

# %%
df.describe()
# Out:
#        Exchange_Rate    Population         GNI_pc  \
# count   1.051200e+04  1.051200e+04   10512.000000
# mean    3.419846e+02  2.851523e+07    8965.564593
# std     1.941857e+03  1.141296e+08   17070.205895
# min     4.300000e-14  4.359000e+03      34.000000
# 25%     1.000000e+00  6.330615e+05     730.000000
# 50%     2.761315e+00  5.051556e+06    2316.500000
# 75%     4.806684e+01  1.678862e+07    8965.750000
# max     4.200000e+04  1.425893e+09  234317.000000
#
#        Agriculture_Hunting_Forestry_Fishing  Inventory_Changes  Construction  \
# count                          1.039100e+04       8.671000e+03  1.051200e+04
# mean                           7.793212e+09       1.626543e+09  1.002199e+10
# std                            4.034349e+10       8.932353e+09  4.985596e+10
# min                            2.813900e+04      -1.510000e+11  1.577280e+05
# 25%                            1.304522e+08       4.673545e+05  6.815523e+07
# ...

# %% [markdown]
# Problema solucionado

# %% [markdown]
# ## <B><FONT COLOR=#FCB714> 2.4 </FONT> Creamos variables </FONT>

# %% [markdown]
# En este proyecto hay carpetas con partes de código que producen unos resultados que traeremos directamente aquí para no ralentizar el Notebook principal. Quedan a disposición del que quiera echarles un ojo

# %% [markdown]
# ### Continente

# %%
# Definimos una función para obtener el continente de un país
def country_to_continent(country_name):
    """
    Creamos una función con la que podamos obtener el continente de un país. Para ello, utilizaremos la librería pycountry_convert.

    Args:
    country_name: str - Nombre del país

    Returns:
    continent_name: str - Nombre del continente
    """
    try:
        # Obtenemos el código del país
        country_alpha2 = pc.country_name_to_country_alpha2(country_name)

        # Obtenemos el código de continente a partir del código de país
        continent_code = pc.country_alpha2_to_continent_code(country_alpha2)

        # Convertimos el código de continente a nombre de continente
        continent_name = pc.convert_continent_code_to_continent_name(continent_code)
        return continent_name
    except:
        # Devolver 'Unknown' para excepciones, es decir, cuando no se puede obtener el código el país 
        return "Unknown"

# Aplicamos la función para crear una nueva columna de continentes 
df['Continent'] = df['Country'].apply(country_to_continent)

# %%
df["Continent"].value_counts()
# Out:
# Africa           2588
# Asia             2005
# Europe           1936
# North America    1629
# Unknown          1002
# Oceania           832
# South America     520
# Name: Continent, dtype: int64

# %% [markdown]
# Vemos que hay algunos países de los que no se ha podido obtener su código y ha devuelto como valor de continente un Unknown. Para arreglar esto, vamos a ver qué países se han quedado fuera de la función y vamos a colocarlos manualmente

# %%
unknown = df[df["Continent"] == "Unknown"]["Country"].unique()
unknown
# Out:
# array(['Bolivia (Plurinational State of)', 'D.R. of the Congo',
#        'Czechoslovakia (Former)', 'Ethiopia (Former)',
#        'State of Palestine', 'China, Hong Kong SAR',
#        'Iran (Islamic Republic of)', 'D.P.R. of Korea',
#        'Republic of Korea', 'Kosovo', "Lao People's DR",
#        'China, Macao SAR', 'Former Netherlands Antilles',
#        'Sint Maarten (Dutch part)', 'Micronesia (FS of)', 'Timor-Leste',
#        'St. Vincent and the Grenadines', 'Yemen Democratic (Former)',
#        'Sudan (Former)', 'USSR (Former)', 'U.R. of Tanzania: Mainland',
#        'Zanzibar', 'Venezuela (Bolivarian Republic of)',
#        'Yemen Arab Republic (Former)', 'Yugoslavia (Former)'],
#       dtype=object)

# %% [markdown]
# Paso 2 (sí, hemos tenido una buena clase de repaso de geografía)

# %%
Africa = ['D.R. of the Congo', 'Ethiopia (Former)', 'Sudan (Former)', 'U.R. of Tanzania: Mainland', 'Zanzibar']
Asia = ['State of Palestine', 'China, Hong Kong SAR', 'Iran (Islamic Republic of)','USSR (Former)', 'Yemen Arab Republic (Former)', 
        'D.P.R. of Korea', 'Republic of Korea', "Lao People's DR", 'China, Macao SAR', 'Micronesia (FS of)', 'Yemen Democratic (Former)', 'Timor-Leste'] 
Europe =['Czechoslovakia (Former)', 'Yugoslavia (Former)', 'Kosovo', 'Former Netherlands Antilles', 'Sint Maarten (Dutch part)']
South_America =['Bolivia (Plurinational State of)', 'St. Vincent and the Grenadines', 'Venezuela (Bolivarian Republic of)']

df['Continent'] = df.apply(
    lambda row: 'Africa' if row['Continent'] == 'Unknown' and row['Country'] in Africa else
                'Asia' if row['Continent'] == 'Unknown' and row['Country'] in Asia else
                'Europe' if row['Continent'] == 'Unknown' and row['Country'] in Europe else
                'South America' if row['Continent'] == 'Unknown' and row['Country'] in South_America else
                row['Continent'],
    axis=1
)

# %% [markdown]
# Aplicamos una lista por comprensión en la que, a cada fila del dataframe, si Continent era Unknown y, simultáneamente, el país en Country aparece en la lista que hemos creado de países de Africa, entonces se sustituye Unknown por Africa. Este proceso se repite para cada continente en el que hubo problemas de adjudicación hasta que no haya ningún Unknown

# %%
df['Continent'].value_counts()
# Out:
# Africa           2789
# Asia             2516
# Europe           2070
# North America    1629
# Oceania           832
# South America     676
# Name: Continent, dtype: int64

# %% [markdown]
# Consideramos que esta variable puede ser de interés en tanto y en cuanto sirve para categorizar los datos, pensando de cara a una visualización más cómoda en gráficos y mapas

# %% [markdown]
# ### Mining & Utilities

# %% [markdown]
# Podemos obtener esta variable como la diferencia enter Mining, Manufacturing & Utilities y Mining

# %%
df["Mining_Utilities"] = df["Mining_Manufacturing_Utilities"] - df["Manufacturing"]

# %% [markdown]
# Para evitar problemas de presencia de multicolinealidad en los datos (la variable Mining_Manufacturing_Utilities sería producto de una combinación lineal de Manufacturing y Mining_Utilities), dropearemos la variable Mining, Manufacturing & Utilities del dataset

# %%
df.drop(columns="Mining_Manufacturing_Utilities",inplace=True)

# %% [markdown]
# ### PIB per cápita

# %% [markdown]
# Una medida para *intentar* representar la riqueza de la población para permitir comparaciones.

# %%
df["GDP_pc"] = df["GDP"]/(df["Population"])

# %% [markdown]
# ### Tasa de crecimiento del PIB

# %% [markdown]
# Calculada como la tasa de variación del PIB respecto al año anterior.

# %%
df["GDP_growth"] = df.groupby("Country")["GDP"].pct_change()*100

# %% [markdown]
# ### Saldo Neto Externo

# %% [markdown]
# También conocida como la Balanza Comercial, representa el superávit o déficit comercial con el sector exterior.

# %%
df["SNE"] = df["Exports"] - df["Imports"]

# %% [markdown]
# ### Índice de Apertura Comercial

# %% [markdown]
# Cálculo del peso conjunto de las exportaciones y las importaciones sobre el total de la economía del país. Indica el peso o importancia que supone el sector exterior en dicho país.

# %%
df["IAC"] = ((df["Exports"] + df["Imports"])/df["GDP"])*100

# %% [markdown]
# ### Tasa de cobertura comercial

# %% [markdown]
# Cálculo del peso que suponen las exportaciones sobre el total de importaciones. Si la ratio es mayor que 1 (>100%), significa que las exportaciones son superiores a las importaciones (SNE>0). Sirve para relativizar un poco el SNE y para poder comparar.

# %%
df["TCC"] = df["Exports"]/df["Imports"]*100

# %% [markdown]
# ### Exportaciones sobre PIB

# %% [markdown]
# Cálculo del peso que suponen las exportaciones sobre el total de la economía. Ayuda a tener una idea de la dependencia que tiene el país de sus exportaciones al extranjero

# %%
df["Exp/GDP"] = (df["Exports"]/df["GDP"])*100

# %% [markdown]
# ### Índice de Desarrollo Humano

# %% [markdown]
# Vamos a obtener algunos datos del IDH. Para ello, obtenemos unos datos de Wikipedia mediante WebScrapping, limpiamos y procesamos los datos y generamos un csv que leemos en este Notebook principal. Tienes disponible ese Notebook en caso de querer consultarlo

# %%
df_transformado = pd.read_csv("Data\IDH.csv")

# %%
df_transformado["Year"] = df_transformado["Year"].astype(str)

# %%
# Fusionamos el df, añadiendole los datos de IDH obtenidos según el país y el año
df_unido = pd.merge(
    df,
    df_transformado,
    left_on=['Country', 'Year'],
    right_on=['Country', 'Year'],
    how='left'
)
df = df_unido
df
# Out:
#            Country  Year  Exchange_Rate  Population Currency  GNI_pc  \
# 0      Afghanistan  1970       0.044998    10752971  Afghani     164
# 1      Afghanistan  1971       0.044998    11015857  Afghani     168
# 2      Afghanistan  1972       0.044998    11286753  Afghani     149
# 3      Afghanistan  1973       0.044998    11575305  Afghani     150
# 4      Afghanistan  1974       0.044998    11869879  Afghani     177
# ...            ...   ...            ...         ...      ...     ...
# 10507       Zambia  2017       9.519501    17298054   Kwacha    1448
# 10508       Zambia  2018      10.458143    17835893   Kwacha    1451
# 10509       Zambia  2019      12.889418    18380477   Kwacha    1246
# 10510       Zambia  2020      18.344093    18927715   Kwacha     928
# 10511       Zambia  2021      20.018487    19473125   Kwacha    1062
#
#        Agriculture_Hunting_Forestry_Fishing  Inventory_Changes  Construction  \
# ...

# %% [markdown]
# ### Desempleo

# %% [markdown]
# Vamos a obtener algunos datos del desempleo. Para ello, obtenemos unos datos de desempleo del Banco Mundial y los procesamos. Después, convertimos el dataframe en un csv para poder leerlo en este Notebook. También tienes disponible ese Notebook

# %% [markdown]
# Cambiamos el tipo de dato de los años a object para que coincida con el tipo de dato de Year en nuestro df principal

# %%
df2 = pd.read_csv(r"Data\Unemployment_filtered.csv")
df2["Year_Unemployment"] = df2["Year_Unemployment"].astype(str)

# %%
# Fusionamos ambos datasets
df_unido = pd.merge(
    df,
    df2,
    left_on=['Country', 'Year'],
    right_on=['Country', 'Year_Unemployment'],
    how='left'
)

# Eliminamos la columna 'Year_Unemployment' ya que es redundante
df_unido.drop(columns=['Year_Unemployment'], inplace=True)

df = df_unido

# %%
df
# Out:
#            Country  Year  Exchange_Rate  Population Currency  GNI_pc  \
# 0      Afghanistan  1970       0.044998    10752971  Afghani     164
# 1      Afghanistan  1971       0.044998    11015857  Afghani     168
# 2      Afghanistan  1972       0.044998    11286753  Afghani     149
# 3      Afghanistan  1973       0.044998    11575305  Afghani     150
# 4      Afghanistan  1974       0.044998    11869879  Afghani     177
# ...            ...   ...            ...         ...      ...     ...
# 10507       Zambia  2017       9.519501    17298054   Kwacha    1448
# 10508       Zambia  2018      10.458143    17835893   Kwacha    1451
# 10509       Zambia  2019      12.889418    18380477   Kwacha    1246
# 10510       Zambia  2020      18.344093    18927715   Kwacha     928
# 10511       Zambia  2021      20.018487    19473125   Kwacha    1062
#
#        Agriculture_Hunting_Forestry_Fishing  Inventory_Changes  Construction  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10512 entries, 0 to 10511
# Data columns (total 33 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   Country                                   10512 non-null  object
#  1   Year                                      10512 non-null  object
#  2   Exchange_Rate                             10512 non-null  float64
#  3   Population                                10512 non-null  int64
#  4   Currency                                  10512 non-null  object
#  5   GNI_pc                                    10512 non-null  int64
#  6   Agriculture_Hunting_Forestry_Fishing      10391 non-null  float64
#  7   Inventory_Changes                         8671 non-null   float64
#  8   Construction                              10512 non-null  float64
#  9   Exports                                   10491 non-null  float64
# ...

# %% [markdown]
# Parece que tenemos muchos nulos, pero en verdad, tenemos 32 datos de desempleo para aproximadamente 152 países

# %% [markdown]
# Finalizado el tratamiento de los datos, generamos un archivo csv con los datos limpios, listos para ser utilizados en otras plataformas como Azure o PowerBI

# %%
df.to_csv("Data/Clean_GEI.csv", index=False)

# %% [markdown]
# # <center><B><FONT COLOR=#FCB714> 3. </FONT> Exploratory Data Analysis </FONT></center>

# %%
df = pd.read_csv("Data\Clean_GEI.csv")

# %% [markdown]
# ## <center><img src="https://analyticsindiamag.com/wp-content/uploads/2021/08/200kb.gif" width="720" height="350"></center> <center><B><FONT COLOR="#FCB714"> 3.1 Graficación </FONT> </center>

# %% [markdown]
# ### Obtención de códigos geográficos de los países

# %% [markdown]
# En el Notebook <FONT COLOR="#FCB714">Codigos_paises</FONT> podrás encontrar un código para obtener los códigos de los países.

# %% [markdown]
# ### Creación de gráficos de barras animados

# %% [markdown]
# En el Notebook <FONT COLOR="#FCB714">Grafico_animado</FONT> podrás encontrar un código para generar un archivo mp4 donde se visualice de forma dinámica un top 15 países según el PIB per capita

# %% [markdown]
# ### Convergencia dentro de la EuroZona?

# %% [markdown]
# Definiremos la Eurozona como el conjunto de países cuya divisa oficial sea el euro.

# %%
Eurozona = df[df["Currency"] == "Euro"].drop(columns=["Currency"])

# %%
Eurozona["Country"].unique()
# Out:
# array(['Andorra', 'Austria', 'Belgium', 'Cyprus', 'Estonia', 'Finland',
#        'France', 'Germany', 'Greece', 'Ireland', 'Italy', 'Kosovo',
#        'Latvia', 'Lithuania', 'Luxembourg', 'Malta', 'Monaco',
#        'Montenegro', 'Netherlands', 'Portugal', 'San Marino', 'Slovakia',
#        'Slovenia', 'Spain'], dtype=object)

# %%
# Creamos una variable en el dataframe Eurozona que indique el GDPpc promedio de todos los paises en cada año
Eurozona["GDPpc_Avg"] = Eurozona.groupby("Year")["GDP_pc"].transform("mean")

# Y una variable que indique la ratio entre el GDPpc de cada país cada año sobre el GDPpc promedio de todos los paises en ese año
Eurozona["GDPpc_Convergency_Ratio"] = (Eurozona["GDP_pc"]/Eurozona["GDPpc_Avg"])*100

# %%
Eurozona
# Out:
#       Country  Year  Exchange_Rate  Population  GNI_pc  \
# 156   Andorra  1970       0.420708       19860    5009
# 157   Andorra  1971       0.417515       21322    5306
# 158   Andorra  1972       0.386279       22832    6285
# 159   Andorra  1973       0.350150       24393    7825
# 160   Andorra  1974       0.346703       26003    9078
# ...       ...   ...            ...         ...     ...
# 8902    Spain  2017       0.885206    46584170   28201
# 8903    Spain  2018       0.846773    46792043   30427
# 8904    Spain  2019       0.893276    47131372   29636
# 8905    Spain  2020       0.875506    47363807   27027
# 8906    Spain  2021       0.845494    47486935   30216
#
#       Agriculture_Hunting_Forestry_Fishing  Inventory_Changes  Construction  \
# 156                           3.952740e+05       1.459897e+06  9.729538e+06
# 157                           4.495210e+05       1.676349e+06  1.106482e+07
# ...

# %%
# Creamos un gráfico de líneas
fig = px.line(Eurozona, x="Year", y="GDPpc_Convergency_Ratio", color="Country", 
                title="GDPpc Convergence Ratio in the Eurozone, in % of Average Eurozone GDPpc", 
                labels={"GDP_Convergence_Ratio": "GDP Convergence Ratio", "Year": "Year", "Country": "Country"})

# Personalizamos los ejes y la leyenda
fig.update_layout(
    xaxis_title="Year",
    yaxis_title="GDPpc Convergence Ratio",
    legend_title="Country"
)

# Añadimos una línea en y=100 para indicar el promedio de la EZ
fig.add_hline(y=100, line_dash="dash", line_color="black")

# Graficamos
fig.show()

# %% [markdown]
# Simplificando un poco la selección de países

# %%
# Definimos qué países de la Eurozona queremos ver y el gráfico de líneas con esos países
Eurozona2 = Eurozona[Eurozona["Country"].isin(["Germany", "France", "Italy", "Spain", "Netherlands", "Belgium", "Portugal", "Greece", "Finland", "Ireland"])]
fig = px.line(Eurozona2, x="Year", y="GDPpc_Convergency_Ratio", color="Country",
                title="GDPpc Convergence Ratio in the Eurozone, in % of Average Eurozone GDPpc",
                labels={"GDP_Convergence_Ratio": "GDP Convergence Ratio", "Year": "Year", "Country": "Country"})

# Personalizamos los ejes y la leyenda
fig.update_layout(
    xaxis_title="Year",
    yaxis_title="GDPpc Convergence Ratio",
    legend_title="Country"
)

# Añadimos una línea en y=100 para indicar el promedio
fig.add_hline(y=100, line_dash="dash", line_color="black")

# Graficamos
fig.show()

# %% [markdown]
# Este gráfico resulta de gran interés en el contexto europeísta. ¿Qué tan beneficioso ha resultado para los países el haberse unido a la Unión Europea / Zona Euro? ¿Hemos ganado todos o acaso hay grandes ganadores y perdedores? ¿Estamos cada vez más cerca o más alejados? Estas pueden ser algunas de las preguntas que surjan al hablar de este tema. Algunos países, como Irlanda, que se unió a la UE en 1973, tienen hoy en día un PIBpc superior a la media y tienen una tendencia fuertemente alcista. Otros, como España, que entró en el 86, tuvieron un impulso que se ha ido perdiendo con el tiempo. Los llamados como "PIGS", Portugal, Italia, Grecia y España, por sus nombres en inglés, son los que peor están, con un PIBpc de entre el 41 y el 71% de la renta media de la Eurozona, en contraposición con otros países del norte como Países Bajos, Irlanda, Bélgica o Finlandia.

# %% [markdown]
# ### Apartado de gráficos

# %% [markdown]
# #### Población Mundial

# %%
df2 = df.groupby(["Continent","Year"])["Population"].sum().reset_index()
df2
# Out:
#          Continent  Year  Population
# 0           Africa  1970   364858669
# 1           Africa  1971   374481531
# 2           Africa  1972   384316274
# 3           Africa  1973   394588710
# 4           Africa  1974   405437540
# ..             ...   ...         ...
# 307  South America  2017   420815184
# 308  South America  2018   424565653
# 309  South America  2019   428135301
# 310  South America  2020   431339959
# 311  South America  2021   434057239
#
# [312 rows x 3 columns]

# %%
# Hacemos un mapeado de colores para cada continente y creamos figura
continent_colors = {
    "Africa": "#FCB714",
    "Asia": "#ee82ee",
    "Europe": "#001489",
    "North America": "#00FFBC",
    "Oceania": "#2ca02c",
    "South America": "#cd853f"
}

fig = sns.lineplot(data=df2, x="Year", y="Population", hue="Continent", palette=continent_colors)
fig.set(xlabel="Year", ylabel="Population", title="Population Evolution by continent, in hispanic thousands of millions of people");

# %% [markdown]
# Se puede ver un salto de población el año del desmantelamiento de la URSS en 1991. La población de Asia y África tienen una fuerte tendencia alcista mientras que el resto de regiones, comparativamente, permanecen prácticamente estáticas

# %% [markdown]
# #### Crecimiento mundial del PIB

# %%
fig = sns.lineplot(data=df, x="Year", y="GDP_growth", errorbar=None, color="#287233");
fig.set(xlabel="Year", ylabel="GDP Growth Rate", title="GDP Growth Rate Evolution in the World, in % of previous year");

# %% [markdown]
# Se puede ver un fenómeno muy debatido hoy en día: si el crecimiento del mundo se está desacelerando, pues el crecimiento del PIB no es tan elevado como en el siglo pasado, ¿será cierto?

# %% [markdown]
# #### Desempleo Mundial

# %%
fig = sns.lineplot(data=df, x="Year", y="Unemployment", errorbar=None, color="#732648")
fig.set(xlabel="Year", ylabel="Unemployment Rate", title="Unemployment Rate Evolution in the World, in % of total labor force");

# %% [markdown]
# Se pueden ver las subidas causadas por las 3 crisis del periodo: lo que parece ser la guerra del golfo, la crisis de 2008 y la pandemia

# %% [markdown]
# #### PIBpc, desempleo y desarrollo humano

# %%
# Definimos el conjunto de datos que queremos usar
GDPpc = df.groupby(["Country","Year"])[["Unemployment","GDP_pc","IDH"]].sum().reset_index()
GDPpc2021 = GDPpc[(GDPpc["Year"] == 2021) & (GDPpc["IDH"] > 0) & (GDPpc["Unemployment"] > 0)] # Eliminamos los valores nulos de desempleo e IDH

# Graficamos
fig = px.scatter(data_frame= GDPpc2021, x="GDP_pc", y="Unemployment", color="IDH", log_x=True, size_max=40, template="plotly_dark", title="GDPpc, Unemployment and HDI relationship in 2021", labels={"GDP_pc": "GDPpc", "Unemployment": "Unemployment"})
fig.update_xaxes(title_text="GDPpc, in USD per person")
fig.update_yaxes(title_text="Unemployment Rate, in % of total labor force")
fig.update_layout(title="GDPpc, Unemployment and HDI relationship in 2021", title_font=dict(size=30, family="Calibri_light", color="white"))
fig.show()

# %% [markdown]
# A mayor PIBpc, parece que tiende a haber menos desempleo y mayor IDH. Tambien, para un mismo PIBpc, subir (aumentar desempleo) parece que perjudica al IDH

# %% [markdown]
# Sabemos que el PIBpc es un componente del IDH, pero incluso añadiendo el Desempleo esta relación parece que se puede leer perfectamente de izquierda a derecha. ¿Es siempre cierto que los países más ricos tienen un mayor IDH? ¿Y menos desempleo?

# %% [markdown]
# #### PIB, PIBpc y desempleo

# %%
# Definimos conjunto de datos
GDP_gr_un = df.groupby(["Country","Year"])[["GDP","GDP_growth","Unemployment"]].sum().reset_index()
GDP_gr_un2021 = GDP_gr_un[(GDP_gr_un["Year"] == 2021) & (GDP_gr_un["Unemployment"] > 0) & (GDP_gr_un["Unemployment"] <= 100)]
GDP_gr_un2021["GDP"] = GDP_gr_un2021["GDP"]/1000 # Pasamos el PIB de Trillions en inglés a billones en español, para que sea más legible para hispanohablantes

# Graficamos
fig = px.scatter(GDP_gr_un2021, x="GDP", y="GDP_growth", color="Unemployment", log_x=True  , size_max=40, template="plotly_dark", title="Relación PIB pc, Desempleo e IDH", labels={"GDP": "PIB", "GDP_growth": "Tasa crecim. PIB"})
fig.update_xaxes(title_text="GDP, in USD, with hispanic billions notation")
fig.update_yaxes(title_text="GDP growth rate, in % of previous year")
fig.update_layout(title="GDP, GDP growth rate and Unemployment relationship in 2021", title_font=dict(size=30, family="Calibri_light", color="white"))
fig.show()

# %% [markdown]
# Parece que a mayor PIB, mayor crecimiento económico, algo curioso pues se suele decir que los países subdesarrollados o en vías de desarrollo, al partir de una base menor, es más fácil (matemáticamente hablando) que alcancen un crecimiento más alto. Por otro lado, también parece que hay más puntos morados en la mitad derecha del gráfico (desempleo bajo) que en la mitad izquierda. ¿Serán estadísticamente significativas estas observaciones?

# %% [markdown]
# #### PIBpc por continente

# %%
# Calculamos el PIBpc promedio de cada continente en toda la series
average = df.groupby("Continent")["GDP_pc"].mean()
average

# Definimos el orden en el que queremos que aparezcan los continentes en el gráfico, que se corresponde con el orden de los valores promedio
continent_order = ["Africa", "Asia", "Europe", "North America", "Oceania", "South America"]

# Indicamos el tamaño que va a tener la figura
plt.figure(figsize=(10, 6))

# Graficamos el salario en USD por nivel de experiencia y le aplicamos algunos ajustes
grafico = sns.stripplot(data=df, x="Continent", y="GDP_pc", orient="v", jitter=0.25, alpha=0.65, palette="rainbow", order=continent_order)
grafico.set_title("GDPpc by Continent")
grafico.set_xlabel("Continent")
grafico.set_ylabel("GDPpc in USD per person")

# Añadimos una línea horizontal para cada nivel de salario promedio
for i, avg in enumerate(average):
    grafico.axhline(avg, color='magenta', linestyle='dashed', linewidth=2, xmin=(i+0.15)/len(average), xmax=(i+0.85)/len(average))
    print(f"El PIBpc promedio de {average.index[i]} durante el periodo es de {float(avg):.2f} USD")

plt.show()
# Out:
# El PIBpc promedio de Africa durante el periodo es de 1465.90 USD
# El PIBpc promedio de Asia durante el periodo es de 7314.67 USD
# El PIBpc promedio de Europe durante el periodo es de 22302.89 USD
# El PIBpc promedio de North America durante el periodo es de 12331.72 USD
# El PIBpc promedio de Oceania durante el periodo es de 7340.55 USD
# El PIBpc promedio de South America durante el periodo es de 4013.57 USD

# %% [markdown]
# ¿Tienen Asia y América del Norte un nivel de PIBpc históricamente parecido? ¿Y si comparamos África con Sudamérica?

# %% [markdown]
# #### Crecimiento del PIB por continente en diversos periodos

# %%
# Calculamos el crecimiento promedio del PIB de cada continente durante el periodo 1991-2021
df2 = df.copy()
df2 = df2[df2["Year"] >= 1991]
average = df2.groupby("Continent")["GDP_growth"].mean()

continent_order = ["Africa", "Asia", "Europe", "North America", "Oceania", "South America"]

# Indicamos el tamaño que va a tener la figura
plt.figure(figsize=(12, 8))

# Graficamos el salario en USD por nivel de experiencia y le aplicamos algunos ajustes
grafico = sns.stripplot(data=df2, x="Continent", y="GDP_growth", orient="v", jitter=0.25, alpha=0.65, palette="rainbow", order=continent_order)
grafico.set_title("GDP growth rate by continent, during period 1991-2021")
grafico.set_xlabel("Continent")
grafico.set_ylabel("GDP growth rate, in % of previous year")

# Añadimos una línea horizontal para cada nivel de salario promedio
for i, avg in enumerate(average):
    grafico.axhline(avg, color='magenta', linestyle='dashed', linewidth=2, xmin=(i+0.15)/len(average), xmax=(i+0.85)/len(average))
    print(f"El crecimiento promedio del PIB de {average.index[i]} durante el periodo es de {float(avg):.2f}%")

plt.show()
# Out:
# El crecimiento promedio del PIB de Africa durante el periodo es de 6.13%
# El crecimiento promedio del PIB de Asia durante el periodo es de 7.59%
# El crecimiento promedio del PIB de Europe durante el periodo es de 5.05%
# El crecimiento promedio del PIB de North America durante el periodo es de 5.19%
# El crecimiento promedio del PIB de Oceania durante el periodo es de 5.42%
# El crecimiento promedio del PIB de South America durante el periodo es de 6.65%

# %% [markdown]
# Vemos que Asia tiene el crecimiento promedio más elevado del periodo, mientras que Europa y América del Norte se quedan un poco atrás

# %%
# Calculamos el crecimiento promedio del PIB de cada continente durante el periodo 2010-2021
df2 = df.copy()
df2 = df2[df2["Year"] >= 2010]
average = df2.groupby("Continent")["GDP_growth"].mean()
average

continent_order = ["Africa", "Asia", "Europe", "North America", "Oceania", "South America"]

# Indicamos el tamaño que va a tener la figura
plt.figure(figsize=(12, 8))

# Graficamos el salario en USD por nivel de experiencia y le aplicamos algunos ajustes
grafico = sns.stripplot(data=df2, x="Continent", y="GDP_growth", orient="v", jitter=0.25, alpha=0.65, palette="rainbow", order=continent_order)
grafico.set_title("GDP growth rate by continent, during period 2010-2021")
grafico.set_xlabel("Continent")
grafico.set_ylabel("GDP growth rate, in % of previous year")

# Añadimos una línea horizontal para cada nivel de salario promedio
for i, avg in enumerate(average):
    grafico.axhline(avg, color='magenta', linestyle='dashed', linewidth=2, xmin=(i+0.15)/len(average), xmax=(i+0.85)/len(average))
    print(f"El crecimiento promedio del PIB de {average.index[i]} durante el periodo es de {float(avg):.2f}%")

plt.show()
# Out:
# El crecimiento promedio del PIB de Africa durante el periodo es de 5.22%
# El crecimiento promedio del PIB de Asia durante el periodo es de 5.36%
# El crecimiento promedio del PIB de Europe durante el periodo es de 3.00%
# El crecimiento promedio del PIB de North America durante el periodo es de 3.17%
# El crecimiento promedio del PIB de Oceania durante el periodo es de 4.65%
# El crecimiento promedio del PIB de South America durante el periodo es de 3.62%

# %% [markdown]
# Si reducimos el periodo de tiempo, la fotografía es casi la misma, pero con datos más reducidos, ¿realmente se está desacelerando el mundo?

# %%
# Ahora a la inversa, vamos a calcular el crecimiento promedio del PIB de cada continente durante el periodo 1970-1990
df2 = df.copy()
df2 = df2[df2["Year"] <= 1990]
average = df2.groupby("Continent")["GDP_growth"].mean()
average

continent_order = ["Africa", "Asia", "Europe", "North America", "Oceania", "South America"]

# Indicamos el tamaño que va a tener la figura
plt.figure(figsize=(12, 8))

# Graficamos el salario en USD por nivel de experiencia y le aplicamos algunos ajustes
grafico = sns.stripplot(data=df2, x="Continent", y="GDP_growth", orient="v", jitter=0.25, alpha=0.65, palette="rainbow", order=continent_order)
grafico.set_title("GDP growth rate by continent, during period 1970-1990")
grafico.set_xlabel("Continent")
grafico.set_ylabel("GDP growth rate, in % of previous year")

# Añadimos una línea horizontal para cada nivel de salario promedio
for i, avg in enumerate(average):
    grafico.axhline(avg, color='magenta', linestyle='dashed', linewidth=2, xmin=(i+0.15)/len(average), xmax=(i+0.85)/len(average))
    print(f"El crecimiento promedio del PIB de {average.index[i]} durante el periodo es de {float(avg):.2f}%")

plt.show()
# Out:
# El crecimiento promedio del PIB de Africa durante el periodo es de 10.22%
# El crecimiento promedio del PIB de Asia durante el periodo es de 12.18%
# El crecimiento promedio del PIB de Europe durante el periodo es de 11.33%
# El crecimiento promedio del PIB de North America durante el periodo es de 11.46%
# El crecimiento promedio del PIB de Oceania durante el periodo es de 9.86%
# El crecimiento promedio del PIB de South America durante el periodo es de 9.55%

# %% [markdown]
# En periodos más antiguos de la serie, Asia, Europa y América del Norte estaban en cabeza, pero en general los datos eran superiores

# %% [markdown]
# #### Crecimiento del PIB por continentes

# %%
# Mapeamos los colores de los continentes
continent_colors = {
    "Africa": "#FCB714",
    "Asia": "#ee82ee",
    "Europe": "#001489",
    "North America": "#00FFBC",
    "Oceania": "#2ca02c",
    "South America": "#cd853f"
}

# Creamos un gráfico de líneas
plt.figure(figsize=(12, 8))
fig = sns.lineplot(data=df, x="Year", y="GDP_growth", hue="Continent", palette=continent_colors, errorbar=None)
fig.set_title("GDP growth rate by continent, in % of previous year, in the period 1970,2021")
fig.set_xlabel("Year")
fig.set_ylabel("GDP growth rate, in % of previous year,")
fig.set_xticklabels(fig.get_xticklabels(), rotation=55)

# Creamos una leyenda personalizada
handles = [plt.Line2D([0], [0], marker='o', color='w', label=continent,
                        markerfacecolor=color, markersize=10) for continent, color in continent_colors.items()]
plt.legend(title='Continent', handles=handles, bbox_to_anchor=(1.05, 1), loc='upper left')

fig
# Out:
# <Axes: title={'center': 'GDP growth rate by continent, in % of previous year, in the period 1970,2021'}, xlabel='Year', ylabel='GDP growth rate, in % of previous year,'>

# %% [markdown]
# Vemos cómo fluctúa la velocidad de crecimiento de continentes a lo largo de los años. Europa parece que tiene algunos de los picos localmente más altos (y más bajos) que los demás en varios periodos, junto con Asia, Oceanía y Sudamérica, aparentemente, mientras que África y Norteamérica han tenido un crecimiento más moderado

# %% [markdown]
# ## <B><FONT COLOR=#FCB714> 3.2 </FONT> Estadística </FONT>

# %% [markdown]
# - AB Testing
# - Obtención de evidencia estadística para conclusiones
# - Ayuda para saber qué variables son relevantes para la predicción

# %% [markdown]
# #### <FONT COLOR=#FCB714> 1. </FONT> Hipótesis nula: los paises con más de 10k de pib pc en 2021 tuvieron un desempleo inferior a los que tenian menos de 10k

# %%
# Definimos el conjunto de datos que queremos usar
GDPpc = df.groupby(["Country","Year"])[["Unemployment","GDP_pc","IDH"]].sum().reset_index()
GDPpc2021 = GDPpc[(GDPpc["Year"] == 2021) & (GDPpc["IDH"] > 0) & (GDPpc["Unemployment"] > 0)] # Eliminamos los valores nulos de desempleo e IDH

# Graficamos
fig = px.scatter(data_frame= GDPpc2021, x="GDP_pc", y="Unemployment", color="IDH", log_x=True, size_max=40, template="plotly_dark", title="GDPpc, Unemployment and HDI relationship in 2021", labels={"GDP_pc": "GDPpc", "Unemployment": "Unemployment", "IDH":"HDI"})
fig.update_xaxes(title_text="GDPpc, in USD per person")
fig.update_yaxes(title_text="Unemployment Rate, in % of total labor force")
fig.update_layout(title="GDPpc, Unemployment and HDI relationship in 2021", title_font=dict(size=30, family="Calibri_light", color="white"))
fig.show()

# %%
# Segmentamos los datos en dos grupos basados en el PIB per cápita
group_high_gdp = df[(df["Year"] == 2021) & (df["GDP_pc"] > 10000)]["Unemployment"].dropna()
group_low_gdp = df[(df["Year"] == 2021) & (df["GDP_pc"] <= 10000)]["Unemployment"].dropna()

# Hacemos un test T
t_stats, p_value = stats.ttest_ind(group_high_gdp, group_low_gdp)

print('T-estadístico:', t_stats, 'P-value:', p_value)

if p_value < 0.05:
    print('Rechazamos la hipótesis nula de que las tasas de desempleo son iguales entre países con un PIB per cápita mayor y menor a 10k en 2021')
else:
    print('No rechazamos la hipótesis nula de que las tasas de desempleo son iguales entre países con un PIB per cápita mayor y menor a 10k en 2021')
# Out:
# T-estadístico: -3.352318370598611 P-value: 0.0010001791300546922
# Rechazamos la hipótesis nula de que las tasas de desempleo son iguales entre países con un PIB per cápita mayor y menor a 10k en 2021

# %% [markdown]
# Existe evidencia estadística de que las tasas de desempleo son inferiores o tienden a ser inferiores en tramos de PIB pc superiores y viceversa

# %% [markdown]
# #### <FONT COLOR=#FCB714> 2. </FONT> Hipótesis nula: a mayor PIBpc mayor IDH (anterior gráfico)

# %%
# Segmentamos los datos en dos grupos basados en el PIB per cápita
group_high_gdp = df[(df["Year"] == 2021) & (df["GDP_pc"] > 10000)]["IDH"].dropna()
group_low_gdp = df[(df["Year"] == 2021) & (df["GDP_pc"] <= 10000)]["IDH"].dropna()

# Hacemos un test T
t_stats, p_value = stats.ttest_ind(group_high_gdp, group_low_gdp)

print('T-estadístico:', t_stats, 'P-value:', p_value)

if p_value < 0.05:
    print('Rechazamos la hipótesis nula de que el IDH promedio entre países con un PIB per cápita mayor y menor a 10k en 2021')
else:
    print('No Rechazamos la hipótesis nula de que el IDH promedio entre países con un PIB per cápita mayor y menor a 10k en 2021')
# Out:
# T-estadístico: 15.099710058209652 P-value: 3.6680270472628606e-33
# Rechazamos la hipótesis nula de que el IDH promedio entre países con un PIB per cápita mayor y menor a 10k en 2021

# %% [markdown]
# De la misma manera, existe evidencia estadística de que el IDH tiende a ser más elevado en tramos de PIB pc superiores y viceversa

# %% [markdown]
# #### ¿Y si partimos más el tramo de PIBpc?

# %%
# Segmentamos en 3 tramos de PIBpc
df2=df.copy()
df2=df2[df2["Year"] == 2021]
df2['GDP_category'] = df2['GDP_pc'].apply(lambda x: 'High' if x > 10000 else('Low' if x < 3000 else 'Medium'))

# Separamos los datos en 3 grupos en funcion del GDP_pc
idh_high = df2[df2['GDP_category'] == 'High']['IDH'].dropna()
idh_medium = df2[df2['GDP_category'] == 'Medium']['IDH'].dropna()
idh_low = df2[df2['GDP_category'] == 'Low']['IDH'].dropna()
unemployment_high = df2[df2['GDP_category'] == 'High']['Unemployment'].dropna()
unemployment_medium = df2[df2['GDP_category'] == 'Medium']['Unemployment'].dropna()
unemployment_low = df2[df2['GDP_category'] == 'Low']['Unemployment'].dropna()

# Test ANOVA
anova_idh = stats.f_oneway(idh_high, idh_medium, idh_low)
anova_unemployment = stats.f_oneway(unemployment_high, unemployment_medium, unemployment_low)

print(f"ANOVA para IDH: estadístico F = {anova_idh.statistic}, valor p = {anova_idh.pvalue}")

if anova_idh.pvalue < 0.05:
    print('Rechazamos la hipótesis nula de que el IDH promedio en 2021 es igual entre los grupos, por lo que es diferente entre, al menos 2 de los grupos de países definidos por tramos de PIB pc')
else:
    print('No Rechazamos la hipótesis nula de que el IDH promedio en 2021 es igual entre los grupos de países definidos por tramos de PIB pc')

print()
print(f"ANOVA para Desempleo: estadístico F = {anova_unemployment.statistic}, valor p = {anova_unemployment.pvalue}")

if anova_unemployment.pvalue < 0.05:
    print('Rechazamos la hipótesis nula de que la tasa de desempleo promedio en 2021 es igual entre los grupos, por lo que es diferente entre, al menos 2 de los grupos de países definidos por tramos de PIB pc ')
else:
    print('No Rechazamos la hipótesis nula de que la tasa de desempleo promedio en 2021 es igual entre los grupos de países definidos por tramos de PIBpc')
# Out:
# ANOVA para IDH: estadístico F = 342.2267823995034, valor p = 5.618731002722533e-60
# Rechazamos la hipótesis nula de que el IDH promedio en 2021 es igual entre los grupos, por lo que es diferente entre, al menos 2 de los grupos de países definidos por tramos de PIB pc
#
# ANOVA para Desempleo: estadístico F = 14.184553050978646, valor p = 2.1457621803143673e-06
# Rechazamos la hipótesis nula de que la tasa de desempleo promedio en 2021 es igual entre los grupos, por lo que es diferente entre, al menos 2 de los grupos de países definidos por tramos de PIB pc

# %% [markdown]
# Efectivamente, si sabemos que los tramos por encima y debajo de 10k son diferentes, realizar un test ANOVA con los tramos más desglosados es muy probable que devuelva la misma conclusión, pues al menos 2 de los 3 grupos no son iguales

# %% [markdown]
# #### <FONT COLOR=#FCB714> 3.  </FONT>Hipótesis nula: los paises con más de 30 mil millones de PIB crecen más que los países con menos de 30mM de PIB en 2021

# %%
# Definimos conjunto de datos
GDP_gr_un = df.groupby(["Country","Year"])[["GDP","GDP_growth","Unemployment"]].sum().reset_index()
GDP_gr_un2021 = GDP_gr_un[(GDP_gr_un["Year"] == 2021) & (GDP_gr_un["Unemployment"] > 0) & (GDP_gr_un["Unemployment"] <= 100)]
GDP_gr_un2021["GDP"] = GDP_gr_un2021["GDP"]/1000 # Pasamos el PIB de Trillions en inglés a billones en español, para que sea más legible para hispanohablantes

# Graficamos
fig = px.scatter(GDP_gr_un2021, x="GDP", y="GDP_growth", color="Unemployment", log_x=True  , size_max=40, template="plotly_dark", title="Relación PIB pc, Desempleo e IDH")
fig.update_xaxes(title_text="GDP, in USD, with hispanic billions notation")
fig.update_yaxes(title_text="GDP growth rate, in % of previous year")
fig.update_layout(title="GDP, GDP growth rate and Unemployment relationship in 2021", title_font=dict(size=30, family="Calibri_light", color="white"))
fig.show()

# %%
# Filtramos los datos para usar solo 2021
df_2021 = df[df['Year'] == 2021]

# Separamos los paises en dos en función de su PIB
gdp_high = df_2021[df_2021['GDP'] > 30e9]['GDP_growth']
gdp_low = df_2021[df_2021['GDP'] <= 30e9]['GDP_growth']

# Nos aseguramos de que no haya NAN que afecten 
gdp_high = gdp_high.dropna()
gdp_low = gdp_low.dropna()

# Hacemos la prueba t student
t_stats, p_value = stats.ttest_ind(gdp_high, gdp_low) # Evaluamos si las medias de ambos grupos son iguales
print('T-estadístico:', t_stats, 'P-value:', p_value)

if p_value < 0.05:
    print('Rechazamos la hipótesis nula de que Los paises con más de 30mM de PIB tienen el mismo crecimiento que los países con menos de 30mM de PIB en 2021')
else:
    print('No Rechazamos la hipótesis nula de que Los paises con más de 30mM de PIB tienen el mismo crecimiento que los países con menos de 30mM de PIB en 2021')
# Out:
# T-estadístico: 2.06481300794897 P-value: 0.04016903436610061
# Rechazamos la hipótesis nula de que Los paises con más de 30mM de PIB tienen el mismo crecimiento que los países con menos de 30mM de PIB en 2021

# %% [markdown]
# Existe evidencia estadística de que los países por encima de los 30mM de USD de PIB tienden a tener un crecimiento del PIB superior

# %% [markdown]
# #### <FONT COLOR=#FCB714> 4. </FONT> Hipótesis nula: los paises con más de 30mM de PIB tienen menos paro que los países con menos de 30mM de PIB en 2021

# %%
# Filtramos para 2021
df_2021 = df[df['Year'] == 2021]

# Separamos los paises en funcion de su PIB (mayores de 30B y menores de 30B) junto a Employment
unemployment_high_gdp = df_2021[df_2021['GDP'] > 30e9]['Unemployment']
unemployment_low_gdp = df_2021[df_2021['GDP'] <= 30e9]['Unemployment']

# Dropeamos NAN's para evitar fallos
unemployment_high_gdp = unemployment_high_gdp.dropna()
unemployment_low_gdp = unemployment_low_gdp.dropna()

# Hacemos la prueba t student
t_stats, p_value = stats.ttest_ind(unemployment_high_gdp, unemployment_low_gdp) 

print('T-estadístico:', t_stats, 'P-value:', p_value)

if p_value < 0.05:
    print('Rechazamos la hipótesis nula de que Los paises con más de 30mM de PIB tienen el mismo paro que los países con menos de 30mM de PIB en 2021')
else:
    print('No Rechazamos la hipótesis nula de que Los paises con más de 30mM de PIB tienen el mismo paro que los países con menos de 30mM de PIB en 2021')
# Out:
# T-estadístico: -2.1150011831325117 P-value: 0.035978839981709095
# Rechazamos la hipótesis nula de que Los paises con más de 30mM de PIB tienen el mismo paro que los países con menos de 30mM de PIB en 2021

# %% [markdown]
# Existe evidencia estadística de que los países con más de 30mM de USD de PIB tienen un desempleo menor

# %% [markdown]
# #### <FONT COLOR=#FCB714> 5. </FONT> Hipotesis nula: Asia y NA tienen un nivel de riqueza historico (pibpc) parecido

# %%
# Calculamos el PIBpc promedio de Asia y Norteamérica
average = df.copy()
average = average[average['Continent'].isin(['Asia', 'North America'])]
average = average.groupby("Continent")["GDP_pc"].mean()
average

continent_order = ["Asia","North America"]

# Indicamos el tamaño que va a tener la figura
plt.figure(figsize=(10, 6))

# Graficamos el salario en USD por nivel de experiencia y le aplicamos algunos ajustes
grafico = sns.stripplot(data=df, x="Continent", y="GDP_pc", orient="v", jitter=0.25, alpha=0.65, palette="rainbow", order=continent_order)
grafico.set_title("GDPpc by continent, in USD per person")
grafico.set_xlabel("Continent")
grafico.set_ylabel("GDPpc")

# Añadimos una línea horizontal para cada nivel de salario promedio
for i, avg in enumerate(average):
    grafico.axhline(avg, color='magenta', linestyle='dashed', linewidth=2, xmin=(i+0.15)/len(average), xmax=(i+0.85)/len(average))
    print(f"El PIBpc promedio de {average.index[i]} durante el periodo es de {float(avg):.2f} USD")

plt.show()
# Out:
# El PIBpc promedio de Asia durante el periodo es de 7314.67 USD
# El PIBpc promedio de North America durante el periodo es de 12331.72 USD

# %%
#Filtramos el df para Asia Y Norte América
df_asia_na = df[df['Continent'].isin(['Asia', 'North America'])]

# Separamos los datos para los dos países y limpiamos posibles nulos
gdp_pc_asia = df_asia_na[df_asia_na['Continent'] == 'Asia']['GDP_pc'].dropna()  
gdp_pc_na = df_asia_na[df_asia_na['Continent'] == 'North America']['GDP_pc'].dropna()

t_stat, p_value = stats.ttest_ind(gdp_pc_asia, gdp_pc_na)
print(f"T-statistic: {t_stat}, P-value: {p_value}")

if p_value < 0.05:
    print("Rechazamos la hipótesis nula de que Asia y Norte América tienen un nivel de riqueza histórico (PIB per capita) parecido.")
else:
    print("No rechazamos la hipótesis nula de que Asia y Norte América tienen un nivel de riqueza histórico (PIB per capita) parecido.")
# Out:
# T-statistic: -10.56761613723486, P-value: 8.936484758016779e-26
# Rechazamos la hipótesis nula de que Asia y Norte América tienen un nivel de riqueza histórico (PIB per capita) parecido.

# %% [markdown]
# Existe evidencia estadística de que el nivel promedio de PIBpc de Asia y Norte América no es el mismo, siendo superior el de este último

# %% [markdown]
# #### <FONT COLOR=#FCB714> 5.2 </FONT> Hipotesis nula: Africa y South America tambien

# %%
# Calculamos el PIBpc promedio en África y Sudamérica
average = df.copy()
average = average[average['Continent'].isin(['Africa', 'South America'])]
average = average.groupby("Continent")["GDP_pc"].mean()
average

continent_order = ["Africa","South America"]

# Indicamos el tamaño que va a tener la figura
plt.figure(figsize=(10, 6))

# Graficamos el salario en USD por nivel de experiencia y le aplicamos algunos ajustes
grafico = sns.stripplot(data=df, x="Continent", y="GDP_pc", orient="v", jitter=0.25, alpha=0.65, palette="rainbow", order=continent_order)
grafico.set_title("GDPpc by continent, in USD per person")
grafico.set_xlabel("Continent")
grafico.set_ylabel("GDPpc")

# Añadimos una línea horizontal para cada nivel de salario promedio
for i, avg in enumerate(average):
    grafico.axhline(avg, color='magenta', linestyle='dashed', linewidth=2, xmin=(i+0.15)/len(average), xmax=(i+0.85)/len(average))
    print(f"El PIBpc promedio de {average.index[i]} durante el periodo es de {float(avg):.2f} USD")

plt.show()
# Out:
# El PIBpc promedio de Africa durante el periodo es de 1465.90 USD
# El PIBpc promedio de South America durante el periodo es de 4013.57 USD

# %%
#Filtramos el df para África Y Sudamérica
df_africa_sa = df[df['Continent'].isin(['Africa', 'South America'])]

# Separamos los datos para los dos países y limpiamos posibles nulos
gdp_pc_africa = df_africa_sa[df_africa_sa['Continent'] == 'Africa']['GDP_pc'].dropna()  
gdp_pc_sa = df_africa_sa[df_africa_sa['Continent'] == 'South America']['GDP_pc'].dropna()

t_stat, p_value = stats.ttest_ind(gdp_pc_africa, gdp_pc_sa)
print(f"T-statistic: {t_stat}, P-value: {p_value}")

if p_value < 0.05:
    print("Rechazamos la hipótesis nula de que África y Sudamérica tienen un nivel de riqueza histórico (PIB per capita) parecido.")
else:
    print("No rechazamos la hipótesis nula de que África y Sudamérica tienen un nivel de riqueza histórico (PIB per capita) parecido.")
# Out:
# T-statistic: -22.97571483571025, P-value: 7.613133103916132e-109
# Rechazamos la hipótesis nula de que África y Sudamérica tienen un nivel de riqueza histórico (PIB per capita) parecido.

# %% [markdown]
# Razonamiento análogo al caso anterior, con África y Sudamérica, siendo Sudamérica el que queda por encima

# %% [markdown]
# #### <FONT COLOR=#FCB714> 6. </FONT> Hipótesis nula: el crecimiento promedio mundial del PIB ha variado durante el periodo?

# %%
fig = sns.lineplot(data=df, x="Year", y="GDP_growth", errorbar=None, color="#287233");
fig.set(xlabel="Year", ylabel="GDP Growth Rate", title="GDP Growth Rate Evolution in the World, in % of previous year");

# %%
gdp_g1971 = df[df["Year"] == 1971]["GDP_growth"] # Tomamos los valores de crecimiento de PIB de 1971..
gdp_g2019 = df[df["Year"] == 2019]["GDP_growth"] # y de 2019 (antes de la pandemia)

t_stats, p_value = stats.ttest_ind(gdp_g1971, gdp_g2019) # Evaluamos si las medias de ambos grupos son iguales
print('T-estadístico:', t_stats, 'P-value:', p_value)

if p_value < 0.05:
    print('Rechazamos la hipótesis nula de que la media de ambos grupos en tasas de crecimiento del PIB es la misma')
else:
    print('No Rechazamos la hipótesis nula de que la media de ambos grupos en tasas de crecimiento del PIB es la misma')
# Out:
# T-estadístico: 12.729505009190024 P-value: 2.2962094251857915e-31
# Rechazamos la hipótesis nula de que la media de ambos grupos en tasas de crecimiento del PIB es la misma

# %% [markdown]
# Existe evidencia estadística de que la media de crecimiento mundial no es la misma en 1971 y 2019, en los años más recientes este crecimiento es menor

# %% [markdown]
# #### <FONT COLOR=#FCB714> 7. </FONT> Hipótesis nula: El crecimiento económico de la EuroZona y de EEUU ha sido parecido

# %%
ZonaEuro = df[df["Currency"] == "Euro"].drop(columns=["Currency"])
usa = df[df["Country"] == "United States"]

# %%
ZonaEuro1 = ZonaEuro.groupby("Year")["GDP"].sum().reset_index()

# Graficamos los datos de la Eurozona
plt.plot(ZonaEuro['Year'].unique(), ZonaEuro1['GDP'], color='#001489', label='Eurozone')

# Y los de EE.UU.
plt.plot(usa['Year'], usa['GDP'], color='#FCB714', label='United States')

# Añadimos etiquetas y título a los ejes y al gráfico
plt.xlabel('Year')
plt.ylabel('GDP')
plt.title('GDP Evolution, in USD, with hispanic tens of billions notation')
plt.legend()

# Mostramos el gráfico
plt.show()

# %%
t_stats, p_value = stats.ttest_ind(usa["GDP"], ZonaEuro1["GDP"]) # Evaluamos si las medias de ambos grupos son iguales
print('T-estadístico:', t_stats, 'P-value:', p_value)

if p_value < 0.05:
    print('Rechazamos la hipótesis nula de que la media de ambos grupos en crecimiento del PIB es la misma')
else:
    print('No Rechazamos la hipótesis nula de que la media de ambos grupos en crecimiento del PIB es la misma')
# Out:
# T-estadístico: 1.9677896944166942 P-value: 0.05180734254269486
# No Rechazamos la hipótesis nula de que la media de ambos grupos en crecimiento del PIB es la misma

# %% [markdown]
# Los datos utilizados sugieren que no hay diferencia entre los datos del PIB de USA y la EZ, con un pvalor límite del 5,1%. Con un error máximo admisible (nivel de significación) del 5,2%, la hipótesis nula sería rechazada, por lo que este resultado queda un poco en el límite entre si es o no estadísticamente significativo. Estrictamente hablando, no son distintos con un nivel de confianza del 95%

# %% [markdown]
# #### <FONT COLOR=#FCB714> 7.2 </FONT> Hipótesis nula: El crecimiento económico de la EuroZona y de China ha sido parecido

# %%
ZonaEuro = df[df["Currency"] == "Euro"].drop(columns=["Currency"])
china = df[df["Country"] == "China"]

# %%
ZonaEuro1 = ZonaEuro.groupby("Year")["GDP"].sum().reset_index()

# Dibujamos la Eurozona
plt.plot(ZonaEuro['Year'].unique(), ZonaEuro1['GDP'], color='#001489', label='Eurozone')

# Y China
plt.plot(china['Year'], china['GDP'], color='#FF0000', label='China')

# Añadimos etiquetas de nuevo
plt.xlabel('Year')
plt.ylabel('GDP')
plt.title('GDP Evolution, in USD, with hispanic tens of billions notation')
plt.legend()

# Representamos el gráfico
plt.show()

# %%
t_stats, p_value = stats.ttest_ind(china["GDP"], ZonaEuro1["GDP"]) # Evaluamos si las medias de ambos grupos son iguales
print('T-estadístico:', t_stats, 'P-value:', p_value)

if p_value < 0.05:
    print('Rechazamos la hipótesis nula de que la media de ambos grupos en crecimiento del PIB es la misma')
else:
    print('No Rechazamos la hipótesis nula de que la media de ambos grupos en crecimiento del PIB es la misma')
# Out:
# T-estadístico: -4.06935182399679 P-value: 9.313000766846055e-05
# Rechazamos la hipótesis nula de que la media de ambos grupos en crecimiento del PIB es la misma

# %% [markdown]
# Sin embargo, sí que existe evidencia estadística suficiente que apunta que el crecimiento entre la EuroZona y China ha sido distinto. En el propio gráfico se puede apreciar el comportamiento casi lineal de la Zona del Euro y el comportamiento casi exponencial de China

# %% [markdown]
# #### <FONT COLOR=#FCB714> 8. </FONT> Hipótesis nula: El PIB pc entre la EuroZona y USA es similar

# %%
ZonaEuro = df[df["Currency"] == "Euro"].drop(columns=["Currency"])
usa = df[df["Country"] == "United States"]

# %%
# Calculamos el PIBpc promedio de la Eurozona
ZonaEuro2 = ZonaEuro.groupby("Year")["GDP_pc"].mean().reset_index()

# Graficamos los datos de la Eurozona
plt.plot(ZonaEuro['Year'].unique(), ZonaEuro2['GDP_pc'], color='#001489', label='Eurozone')

# Y de EE.UU.
plt.plot(usa['Year'], usa['GDP_pc'], color='#FCB714', label='United States')

# Añadimos etiquetas y título a los ejes y al gráfico
plt.xlabel('Year')
plt.ylabel('GDPpc')
plt.title('GDPpc, in USD per person')
plt.legend()

# Graficamos
plt.show()

# %%
t_stats, p_value = stats.ttest_ind(usa["GDP_pc"], ZonaEuro2["GDP_pc"]) # Evaluamos si las medias de ambos grupos son iguales
print('T-estadístico:', t_stats, 'P-value:', p_value)

if p_value < 0.05:
    print('Rechazamos la hipótesis nula de que el PIB pc promedio es el mismo en ambos grupos')
else:
    print('No Rechazamos la hipótesis nula de que el PIB pc promedio es el mismo en ambos grupos')
# Out:
# T-estadístico: 2.6220219360450088 P-value: 0.010079113595060788
# Rechazamos la hipótesis nula de que el PIB pc promedio es el mismo en ambos grupos

# %% [markdown]
# Aunque similares, existe evidencia estadística de que el PIBpc de la EuroZona y el de USA son distintos

# %% [markdown]
# #### <FONT COLOR=#FCB714> 8.2 </FONT> Hipótesis nula: El PIB pc entre la EuroZona y Korea del Sur es similar

# %%
ZonaEuro = df[df["Currency"] == "Euro"].drop(columns=["Currency"])
Skorea = df[df["Country"] == "Republic of Korea"]

# %%
ZonaEuro2 = ZonaEuro.groupby("Year")["GDP_pc"].mean().reset_index()

# Dibujamos la Eurozona
plt.plot(ZonaEuro['Year'].unique(), ZonaEuro2['GDP_pc'], color='#001489', label='Eurozone')

# Y a Corea del Sur
plt.plot(Skorea['Year'], Skorea['GDP_pc'], color='black', label='South Korea')

# Añadimos las etiquetas y el título
plt.xlabel('Year')
plt.ylabel('GDPpc')
plt.title('GDPpc, in USD per person')
plt.legend()

# Mostramos la gráfica
plt.show()

# %%
t_stats, p_value = stats.ttest_ind(Skorea["GDP_pc"], ZonaEuro2["GDP_pc"]) # Evaluamos si las medias de ambos grupos son iguales
print('T-estadístico:', t_stats, 'P-value:', p_value)

if p_value < 0.05:
    print('Rechazamos la hipótesis nula de que el PIB pc promedio es el mismo en ambos grupos')
else:
    print('No Rechazamos la hipótesis nula de que el PIB pc promedio es el mismo en ambos grupos')
# Out:
# T-estadístico: -4.228302295401471 P-value: 5.1443213724180425e-05
# Rechazamos la hipótesis nula de que el PIB pc promedio es el mismo en ambos grupos

# %% [markdown]
# De la misma forma que antes, Korea del Sur también cuenta con un PIB pc distinto

# %% [markdown]
# ## <center><img src="https://miro.medium.com/v2/resize:fit:1400/1*Ld_9Cuphta9MuaSK71gZmQ.gif" width="720" height="350"></center> <center><B><FONT COLOR="#FCB714"> 3.3 Predicción </FONT> </center>

# %% [markdown]
# En esta última etapa utilizaremos un modelo auto ARIMA y Neural Prophet para obtener predicciones sobre la EuroZona.

# %% [markdown]
# ### Auto ARIMA

# %% [markdown]
# Con un auto ARIMA podremos verificar cual es el mejor modelo dentro de una serie de combinaciones entre los hiperparámetros para la autoregresión (AR) y la media móvil (MA), según un nivel de diferenciación concreto. Como vamos a centrarnos en la Eurozona, vamos a empezar definiendo esa región

# %%
Eurozona = df[df["Currency"] == "Euro"].drop(columns=["Currency"])

# %%
Eurozona.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1108 entries, 156 to 8906
# Data columns (total 32 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   Country                                   1108 non-null   object
#  1   Year                                      1108 non-null   int64
#  2   Exchange_Rate                             1108 non-null   float64
#  3   Population                                1108 non-null   int64
#  4   GNI_pc                                    1108 non-null   int64
#  5   Agriculture_Hunting_Forestry_Fishing      1056 non-null   float64
#  6   Inventory_Changes                         1090 non-null   float64
#  7   Construction                              1108 non-null   float64
#  8   Exports                                   1108 non-null   float64
#  9   Consumption                               1108 non-null   float64
# ...

# %% [markdown]
# Y como vamos a especificar el PIB como nuestra variable objetivo, vamos a agrupar los países por años y calcular la suma del GDP de todos los países en cada año

# %%
Eurozona = Eurozona.groupby("Year")["GDP"].sum().reset_index()
Eurozona
# Out:
#     Year           GDP
# 0   1970  6.379761e+11
# 1   1971  7.242669e+11
# 2   1972  8.739369e+11
# 3   1973  1.134326e+12
# 4   1974  1.285878e+12
# ..   ...           ...
# 47  2017  1.270155e+13
# 48  2018  1.371433e+13
# 49  2019  1.344175e+13
# 50  2020  1.311725e+13
# 51  2021  1.459672e+13
#
# [52 rows x 2 columns]

# %% [markdown]
# Como podemos ver, la serie no es estacionaria en media, por lo que vamos a tener que diferenciarla

# %%
sns.lineplot(data=Eurozona, x="Year", y="GDP", errorbar=None, color="#001489");

# %% [markdown]
# Vamos a ver cuánto tenemos que diferenciar la serie para que sea estacionaria, al menos en media

# %%
sns.lineplot(data=Eurozona, x="Year", y=Eurozona["GDP"].diff(), errorbar=None, color="#001489");

# %% [markdown]
# Con una diferenciación de orden 1 se ve que los datos fluctúan alrededor del cero, por lo que podríamos decir que es estacionaria en media por lo menos, cosa que comprobaremos después. Sin embargo, también se ve que a medida que pasan los años, la volatilidad aumenta, por lo que no es estacionaria en variación.

# %%
sns.lineplot(data=Eurozona, x="Year", y=Eurozona["GDP"].diff().diff(), errorbar=None, color="#001489");

# %% [markdown]
# Aplicando segundas diferencias se puede ver lo mismo que en el caso anterior

# %% [markdown]
# Vamos a testear la si las series son estacionarias o no

# %%
# Hipótesis nula: Existe una raíz unitaria en los datos, por lo que la serie no es estacionaria en media

# Resultados
print(f"p-valor diferenciación orden cero: {adfuller(Eurozona['GDP'])[1]}")
print(f"p-valor diferenciación orden uno: {adfuller(Eurozona['GDP'].diff().dropna())[1]}")
print(f"p-valor diferenciación orden dos: {adfuller(Eurozona['GDP'].diff().diff().dropna())[1]}")
# Out:
# p-valor diferenciación orden cero: 0.9337705060074784
# p-valor diferenciación orden uno: 0.011012043058089062
# p-valor diferenciación orden dos: 4.981607136943672e-17

# %% [markdown]
# Con una diferenciación de orden 1 y 2, seríamos capaces de rechazar la hipótesis nula de que la serie no es estacionaria en media. Vamos a utilizar la diferenciación de orden 1 para perder la menor cantidad de datos posible

# %% [markdown]
# Probaremos con ARIMA(p,1,q). Utilizando un auto ARIMA se probarán automáticamente varios modelos y se seleccionará el que menor criterio de información de Akaike (AIC) tenga

# %%
model = auto_arima(Eurozona['GDP'], start_p=1, start_q=1,
                      test='adf',
                      max_p=5, max_q=5,
                      m=1,             
                      d=1,          
                      seasonal=False,   
                      start_P=0, 
                      D=None, 
                      trace=True,
                      error_action='ignore',  
                      suppress_warnings=True, 
                      stepwise=True)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=2929.606, Time=0.11 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=2928.927, Time=0.01 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=2930.601, Time=0.02 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=2930.393, Time=0.02 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=2934.433, Time=0.01 sec
#
# Best model:  ARIMA(0,1,0)(0,0,0)[0] intercept
# Total fit time: 0.173 seconds

# %% [markdown]
# Se ha detectado automáticamente que el mejor modelo según el AIC es ARIMA(0,1,0)

# %%
# Ajustamos modelo a datos
model = ARIMA(Eurozona['GDP'].values, order=(0,1,0))
model_fit = model.fit()
# Resumen del entrenamiento
print(model_fit.summary())
# Out:
#                                SARIMAX Results
# ...
# Dep. Variable:                      y   No. Observations:                   52
# Model:                 ARIMA(0, 1, 0)   Log Likelihood               -1466.217
# Date:                Thu, 18 Jul 2024   AIC                           2934.433
# Time:                        10:32:27   BIC                           2936.365
# Sample:                             0   HQIC                          2935.171
#                                  - 52
# Covariance Type:                  opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# sigma2      5.375e+23   1.01e+23      5.342      0.000     3.4e+23    7.35e+23
# ...
# Ljung-Box (L1) (Q):                   0.36   Jarque-Bera (JB):                 2.07
# Prob(Q):                              0.55   Prob(JB):                         0.35
# ...

# %%
model_fit.forecast(5) # Predicción de los próximos 5 años (de 2022 a 2026, incluidos ambos)
# Out:
# array([1.45967172e+13, 1.45967172e+13, 1.45967172e+13, 1.45967172e+13,
#        1.45967172e+13])

# %%
Eurozona["GDP"].tail()
# Out:
# 47    1.270155e+13
# 48    1.371433e+13
# 49    1.344175e+13
# 50    1.311725e+13
# 51    1.459672e+13
# Name: GDP, dtype: float64

# %% [markdown]
# Sin embargo estas predicciones no tienen mucho sentido, pues estamos usando como predictor el valor anterior del PIB, por lo que el valor predicho para 2022 va a ser el de 2021, y de ahí en adelante todas las predicciones van a ser el mismo valor

# %% [markdown]
# Vamos a probar con un modelo ARIMA(1,1,1), que es el segundo mejor según el criterio de AIC

# %%
# Ajustamos modelo a datos
model = ARIMA(Eurozona['GDP'].values, order=(1,1,1))
model_fit = model.fit()
# Resumen del entrenamiento
print(model_fit.summary())
# Out:
#                                SARIMAX Results
# ...
# Dep. Variable:                      y   No. Observations:                   52
# Model:                 ARIMA(1, 1, 1)   Log Likelihood               -1463.502
# Date:                Thu, 18 Jul 2024   AIC                           2933.005
# Time:                        10:32:28   BIC                           2938.800
# Sample:                             0   HQIC                          2935.219
#                                  - 52
# Covariance Type:                  opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.4203      0.333     -1.264      0.206      -1.072       0.231
# ma.L1          0.7352      0.237      3.100      0.002       0.270       1.200
# sigma2      5.296e+23   1.16e-25   4.58e+48      0.000     5.3e+23     5.3e+23
# ...

# %%
model_fit.forecast(5) # Predicción de los próximos 5 años (de 2022 a 2026, incluidos ambos)
# Out:
# array([1.49503521e+13, 1.48017326e+13, 1.48641918e+13, 1.48379425e+13,
#        1.48489741e+13])

# %%
Eurozona["GDP"].tail()
# Out:
# 47    1.270155e+13
# 48    1.371433e+13
# 49    1.344175e+13
# 50    1.311725e+13
# 51    1.459672e+13
# Name: GDP, dtype: float64

# %% [markdown]
# En este caso, las predcciones ya no son triviales. Sin embargo, el modelo se espera que la Eurozona esté estancada en los próximos años, cosa que puede ser discutida según los datos del PIB de [Statista](https://es.statista.com/estadisticas/600201/crecimiento-del-pib-en-la-ue-y-la-zona-euro/) y del [Banco Mundial](https://datos.bancomundial.org/indicador/NY.GDP.MKTP.CD?locations=XC), donde se puede ver que la predicción para 2022 no es tan distinta pero a partir de ahí las diferencias se incrementan

# %%
model_fit.plot_diagnostics()
plt.tight_layout()
plt.show()

# %% [markdown]
# Los errores se ven correctos. La media parece que es de cero, parece que siguen una distribución normal y que no hay autocorrelación (correlación entre los errores en dos periodos distintos: en t y en t-s)

# %% [markdown]
# Obtenemos las estimaciones del modelo

# %%
predictions = model_fit.predict()

# %%
error = mean_squared_error(Eurozona['GDP'], predictions) # Calculamos el error cuadrático medio
raizerror = root_mean_squared_error(Eurozona['GDP'], predictions) # Calculamos la raíz del error cuadrático medio
print(f"El error cuadrático medio es: {error}")
print(f"La raíz del error cuadrático medio es: {raizerror}")
# Out:
# El error cuadrático medio es: 4.8866318267289913e+23
# La raíz del error cuadrático medio es: 699044478322.3019

# %% [markdown]
# En un modelo realizado mediante Azure AutoMachine Learning obtuvimos un Root Mean Squared Error de 7.1600e+11

# %%
predictions
# Out:
# array([0.00000000e+00, 7.88460107e+11, 6.43400871e+11, 9.75632775e+11,
#        1.13976954e+12, 1.32871661e+12, 1.52747411e+12, 1.55449211e+12,
#        1.84143443e+12, 2.24426394e+12, 2.71795253e+12, 2.97504628e+12,
#        2.41306418e+12, 2.55674334e+12, 2.33729234e+12, 2.34413273e+12,
#        2.38139648e+12, 3.64640965e+12, 4.15997601e+12, 4.65414992e+12,
#        4.59982493e+12, 6.33785747e+12, 5.88841485e+12, 7.12095032e+12,
#        5.70945906e+12, 6.96741153e+12, 7.50427119e+12, 7.65318571e+12,
#        6.71113624e+12, 7.38695215e+12, 6.92215971e+12, 6.40797541e+12,
#        6.67529239e+12, 7.27974266e+12, 9.28332850e+12, 1.02340549e+13,
#        1.05862127e+13, 1.13432980e+13, 1.32849894e+13, 1.42184849e+13,
#        1.24626221e+13, 1.28944264e+13, 1.37673058e+13, 1.22522236e+13,
#        1.36876396e+13, 1.32563150e+13, 1.13239134e+13, 1.23620484e+13,
#        1.26527328e+13, 1.40691362e+13, 1.30950742e+13, 1.32699310e+13])

# %% [markdown]
# Graficamos los datos reales vs los obtenidos por el modelo

# %%
# Generamos unos intervalos de confianza de +10% y -10% del valor de las predicciones
conf_int_lower = predictions*0.9  # Limite inferior ficticio
conf_int_upper = predictions*1.1  # Limite superior ficticio

# Creamos un DataFrame con los datos de nuestras predicciones y los límites de confianza ficticios anteriormente descritos
df_pred = pd.DataFrame({'Year': Eurozona["Year"], 'Value': predictions, 'Lower': conf_int_lower, 'Upper': conf_int_upper})

# Concatenamos los datos históricos con las predicciones
df_all = pd.concat([Eurozona, df_pred])

# Utilizamos seaborn para empezar a crear el gráfico
sns.set(style="darkgrid") # Estilo del grid de la gráfica

# Establecemos un tamaño
plt.figure(figsize=(12, 6)) # Tamaño de la figura

# Dibujamos los datos reales
sns.lineplot(data=Eurozona, x='Year', y='GDP', label='Histórico', color='#001489')

# Y los valores que predice el modelo
sns.lineplot(data=df_pred, x='Year', y='Value', label='Predicción', color='red', linestyle='--')

# Añadimos un área de confianza ficticio del 10%
plt.fill_between(df_pred['Year'], df_pred['Lower'], df_pred['Upper'], color='red', alpha=0.3)

# Añadimos títulos 
plt.xlabel('Year')
plt.ylabel('GDP')
plt.title('Data and ARIMA predictions of Eurozone GDP, in tens of billions in hispanic notation, with a +-10% confidence interval')
plt.legend()

# %% [markdown]
# El intervalo de confianza anterior creado se dice que es ficticio porque en realidad no está teniendo en cuenta la volatilidad de las predicciones, que sería lo que habría que graficar. Sin embargo, como el modelo tiene heterocedasticidad (varianza no constante a lo largo de la serie), cada vez la volatidad se ha visto que es mayor, por lo que a priori podría ser una forma de intentar graficar un intervalo de confianza alrededor de ese valor

# %% [markdown]
# A continuación vamos a intentar graficar las predicciones futuras del modelo (Forecasting). Para ello, le añadiremos 5 años al dataframe de la Eurozona

# %%
# Definimos una nueva fila añadiendo manualmente los años que se quieran mostrar después en las predicciones
new_rows = pd.DataFrame({
    'Year': [2022, 2023, 2024, 2025, 2026]
})

# Ahora añadimos las filas nuevas al dataframe original, sin observaciones de GDP
Eurozona = pd.concat([Eurozona, new_rows], ignore_index=True)
Eurozona
# Out:
#     Year           GDP
# 0   1970  6.379761e+11
# 1   1971  7.242669e+11
# 2   1972  8.739369e+11
# 3   1973  1.134326e+12
# 4   1974  1.285878e+12
# ..   ...           ...
# 52  2022           NaN
# 53  2023           NaN
# 54  2024           NaN
# 55  2025           NaN
# 56  2026           NaN
#
# [57 rows x 2 columns]

# %% [markdown]
# .. y concatenaremos las predicciones del modelo con las predicciones de los 5 siguientes años.

# %%
predictions = np.concatenate((predictions, model_fit.forecast(5)))
predictions
# Out:
# array([0.00000000e+00, 7.88460107e+11, 6.43400871e+11, 9.75632775e+11,
#        1.13976954e+12, 1.32871661e+12, 1.52747411e+12, 1.55449211e+12,
#        1.84143443e+12, 2.24426394e+12, 2.71795253e+12, 2.97504628e+12,
#        2.41306418e+12, 2.55674334e+12, 2.33729234e+12, 2.34413273e+12,
#        2.38139648e+12, 3.64640965e+12, 4.15997601e+12, 4.65414992e+12,
#        4.59982493e+12, 6.33785747e+12, 5.88841485e+12, 7.12095032e+12,
#        5.70945906e+12, 6.96741153e+12, 7.50427119e+12, 7.65318571e+12,
#        6.71113624e+12, 7.38695215e+12, 6.92215971e+12, 6.40797541e+12,
#        6.67529239e+12, 7.27974266e+12, 9.28332850e+12, 1.02340549e+13,
#        1.05862127e+13, 1.13432980e+13, 1.32849894e+13, 1.42184849e+13,
#        1.24626221e+13, 1.28944264e+13, 1.37673058e+13, 1.22522236e+13,
#        1.36876396e+13, 1.32563150e+13, 1.13239134e+13, 1.23620484e+13,
#        1.26527328e+13, 1.40691362e+13, 1.30950742e+13, 1.32699310e+13,
# ...

# %% [markdown]
# Los valores nuevos, correspondientes a las predicciones de los siguientes 5 años, son los de la penúltima fila, con 4 elementos, y la última, con 1 elemento

# %% [markdown]
# De esta manera, si volvemos a graficar, obtenemos lo siguiente

# %%
# Generamos unos intervalos de confianza de +10% y -10% del valor de las predicciones
conf_int_lower = predictions*0.9  # Limite inferior ficticio
conf_int_upper = predictions*1.1  # Limite superior ficticio

# Creamos un DataFrame con los datos de nuestras predicciones y los límites de confianza ficticios anteriormente descritos
df_pred = pd.DataFrame({'Year': Eurozona["Year"], 'Value': predictions, 'Lower': conf_int_lower, 'Upper': conf_int_upper})

# Concatenamos los datos históricos con las predicciones
df_all = pd.concat([Eurozona, df_pred])

# Utilizamos seaborn para empezar a crear el gráfico
sns.set(style="darkgrid") # Estilo del grid de la gráfica

# Establecemos un tamaño
plt.figure(figsize=(12, 6)) # Tamaño de la figura

# Dibujamos los datos reales
sns.lineplot(data=Eurozona, x='Year', y='GDP', label='Histórico', color='#001489')

# Y los valores que predice el modelo
sns.lineplot(data=df_pred, x='Year', y='Value', label='Predicción', color='red', linestyle='--')

# Añadimos un área de confianza ficticio del 10%
plt.fill_between(df_pred['Year'], df_pred['Lower'], df_pred['Upper'], color='red', alpha=0.3)

# Añadimos títulos 
plt.xlabel('Year')
plt.ylabel('GDP')
plt.title('Data and ARIMA predictions of Eurozone GDP, in tens of billions in hispanic notation, with a +-10% confidence interval')
plt.legend()

# %%
df_all = pd.merge(Eurozona, df_pred, on="Year", how="inner")
df_all.rename(columns={"Value": "ARIMAF"}, inplace=True)
df_all
# Out:
#     Year           GDP        ARIMAF         Lower         Upper
# 0   1970  6.379761e+11  0.000000e+00  0.000000e+00  0.000000e+00
# 1   1971  7.242669e+11  7.884601e+11  7.096141e+11  8.673061e+11
# 2   1972  8.739369e+11  6.434009e+11  5.790608e+11  7.077410e+11
# 3   1973  1.134326e+12  9.756328e+11  8.780695e+11  1.073196e+12
# 4   1974  1.285878e+12  1.139770e+12  1.025793e+12  1.253746e+12
# ..   ...           ...           ...           ...           ...
# 52  2022           NaN  1.495035e+13  1.345532e+13  1.644539e+13
# 53  2023           NaN  1.480173e+13  1.332156e+13  1.628191e+13
# 54  2024           NaN  1.486419e+13  1.337777e+13  1.635061e+13
# 55  2025           NaN  1.483794e+13  1.335415e+13  1.632174e+13
# 56  2026           NaN  1.484897e+13  1.336408e+13  1.633387e+13
#
# [57 rows x 5 columns]

# %% [markdown]
# Nos guardamos los datos de las predicciones de ARIMA por si queremos graficarlos

# %%
df_all.to_csv("Data/ARIMAForecast.csv", index=False)

# %% [markdown]
# ### Aplicamos Neural Prophet

# %% [markdown]
# Volvemos a definir el dataframe con los datos de la Eurozona

# %%
Eurozona = df[df["Currency"] == "Euro"].drop(columns=["Currency"])
Eurozona = Eurozona.groupby("Year")["GDP"].sum().reset_index()
Eurozona
# Out:
#     Year           GDP
# 0   1970  6.379761e+11
# 1   1971  7.242669e+11
# 2   1972  8.739369e+11
# 3   1973  1.134326e+12
# 4   1974  1.285878e+12
# ..   ...           ...
# 47  2017  1.270155e+13
# 48  2018  1.371433e+13
# 49  2019  1.344175e+13
# 50  2020  1.311725e+13
# 51  2021  1.459672e+13
#
# [52 rows x 2 columns]

# %% [markdown]
# Aplicamos las transformaciones necesarias del modelo

# %%
# Renombramos las columnas (deben llamarse exactamente así)
Eurozona.rename(columns = {'Year':'ds', 'GDP':'y'}, inplace = True)

# Cambiamos formato de la variable año a fechas
Eurozona['ds'] = pd.to_datetime(Eurozona['ds'], format='%Y')

# Mostramos info
Eurozona.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ds      52 non-null     datetime64[ns]
#  1   y       52 non-null     float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 960.0 bytes

# %%
Eurozona
# Out:
#            ds             y
# 0  1970-01-01  6.379761e+11
# 1  1971-01-01  7.242669e+11
# 2  1972-01-01  8.739369e+11
# 3  1973-01-01  1.134326e+12
# 4  1974-01-01  1.285878e+12
# ..        ...           ...
# 47 2017-01-01  1.270155e+13
# 48 2018-01-01  1.371433e+13
# 49 2019-01-01  1.344175e+13
# 50 2020-01-01  1.311725e+13
# 51 2021-01-01  1.459672e+13
#
# [52 rows x 2 columns]

# %% [markdown]
# El siguiente código va a generar muchas líneas, pueden ser ocultadas si se hace click en la líneea gris o azul que aparecerá a la izquierda cuando se pone el ratón encima

# %%
# Instanciamos modelo Neural Prophet
m = NeuralProphet()

# Partimos datos especificando la unidad mínima de tiempo (en este caso años) y el porcentaje de datos de validación
df_train, df_val = m.split_df(Eurozona, freq='Y', valid_p = 0.3)

# Entrenamos el modelo
metrics = m.fit(df_train, freq='Y', validation_df=df_val)

# %%
Eurozona
# Out:
#            ds             y
# 0  1970-01-01  6.379761e+11
# 1  1971-01-01  7.242669e+11
# 2  1972-01-01  8.739369e+11
# 3  1973-01-01  1.134326e+12
# 4  1974-01-01  1.285878e+12
# ..        ...           ...
# 47 2017-01-01  1.270155e+13
# 48 2018-01-01  1.371433e+13
# 49 2019-01-01  1.344175e+13
# 50 2020-01-01  1.311725e+13
# 51 2021-01-01  1.459672e+13
#
# [52 rows x 2 columns]

# %% [markdown]
# Vemos las métricas del modelo y las graficamos

# %%
metrics
# Out:
#           MAE_val      RMSE_val  Loss_val  RegLoss_val  epoch           MAE  \
# 0    4.769217e+13  4.770515e+13  4.475150          0.0      0  3.606455e+13
# 1    4.760241e+13  4.761538e+13  4.465788          0.0      1  3.620429e+13
# 2    4.751194e+13  4.752490e+13  4.456350          0.0      2  3.650544e+13
# 3    4.742009e+13  4.743303e+13  4.446768          0.0      3  3.606721e+13
# 4    4.732642e+13  4.733936e+13  4.436997          0.0      4  3.567242e+13
# ..            ...           ...       ...          ...    ...           ...
# 995  1.497059e+12  1.700683e+12  0.015737          0.0    995  3.641326e+11
# 996  1.497059e+12  1.700683e+12  0.015737          0.0    996  3.682340e+11
# 997  1.497059e+12  1.700683e+12  0.015737          0.0    997  3.921023e+11
# 998  1.497059e+12  1.700683e+12  0.015737          0.0    998  4.087576e+11
# 999  1.497059e+12  1.700683e+12  0.015737          0.0    999  4.271816e+11
#
#              RMSE      Loss  RegLoss
# ...

# %%
metrics.drop(['epoch'], axis=1).plot(figsize=(15,4));

# %% [markdown]
# Preparamos los datos para ver las predicciones de n periodos futuros a partir de 2021, según el número que se indique en el siguiente código

# %%
future = m.make_future_dataframe(Eurozona, periods=3, n_historic_predictions=len(Eurozona)) # si periods=0, no se mostrarán predicciones futuras, 
                                                                                            # y añadiremos manualmente los años
forecast = m.predict(future)
forecast['residual1']= forecast['y']-forecast['yhat1']

# %% [markdown]
# Hemos obtenido el dataset con los datos de la serie..

# %%
future
# Out:
#            ds             y
# 0  1970-01-01  6.379761e+11
# 1  1971-01-01  7.242669e+11
# 2  1972-01-01  8.739369e+11
# 3  1973-01-01  1.134326e+12
# 4  1974-01-01  1.285878e+12
# ..        ...           ...
# 50 2020-01-01  1.311725e+13
# 51 2021-01-01  1.459672e+13
# 52 2022-01-01           NaN
# 53 2023-01-01           NaN
# 54 2024-01-01           NaN
#
# [55 rows x 2 columns]

# %% [markdown]
# .. y con las predicciones, así como el error cometido y la tendencia

# %%
forecast
# Out:
#            ds             y         yhat1         trend  season_yearly  \
# 0  1970-01-01  6.379761e+11  3.235794e+11 -1.075797e+13   1.108155e+13
# 1  1971-01-01  7.242669e+11  7.314769e+11 -1.047202e+13   1.120349e+13
# 2  1972-01-01  8.739369e+11  1.135460e+12 -1.018606e+13   1.132152e+13
# 3  1973-01-01  1.134326e+12  1.037785e+12 -9.917927e+12   1.095571e+13
# 4  1974-01-01  1.285878e+12  1.400981e+12 -9.680568e+12   1.108155e+13
# ..        ...           ...           ...           ...            ...
# 50 2020-01-01  1.311725e+13  1.566591e+13  4.344391e+12   1.132152e+13
# 51 2021-01-01  1.459672e+13  1.568109e+13  4.725379e+12   1.095571e+13
# 52 2022-01-01           NaN  1.618687e+13  5.105325e+12   1.108155e+13
# 53 2023-01-01           NaN  1.668877e+13  5.485273e+12   1.120349e+13
# 54 2024-01-01           NaN  1.718674e+13  5.865219e+12   1.132152e+13
#
#        residual1
# 0   3.143966e+11
# 1  -7.210021e+09
# 2  -2.615236e+11
# 3   9.654064e+10
# 4  -1.151024e+11
# ...

# %% [markdown]
# Los 3 últimos datos de la columna yhat es el vector de predicciones de los años 2022, 2023 y 2024, respectivamente. Al contrario que el modelo anterior, que tendía a infraestimar los datos recientes, este parece que tiende a sobreestimar los datos recientes

# %% [markdown]
# Realizamos la misma operación que anteriormente, añadimos años para ver predicciones (Esto se debe ejecutar solamente cuando periods=0 en el bloque de código anterior)

# %%
# # Definimos una nueva fila añadiendo manualmente los años que se quieran mostrar después en las predicciones (3 años en este caso, desde 2021)
# new_rows = pd.DataFrame({
#     'ds': [2022, 2023, 2024],
# })

# # Y añadimos las filas nuevas al dataframe original, sin observaciones de GDP
# future = pd.concat([future, new_rows], ignore_index=True)
# future['ds'] = pd.to_datetime(future['ds'].astype(str))
# future

# %%
# # Y definimos las predicciones
# forecast = m.predict(future)
# forecast['residual1']= forecast['y']-forecast['yhat1']
# forecast

# %%
# Creamos gráfico
f = plt.figure(figsize=(16, 12), dpi=80)
# Preparamos primer componente
ax1 = f.add_subplot(221)
ax1.set_title('Model residuals')
ax1.plot(forecast['residual1'])
# Preparamos segundo componente
ax2 = f.add_subplot(222)
ax2.set_title('Series vs model prediction')
ax2.plot(forecast['y'])
ax2.plot(forecast['yhat1'])
ax2.legend(['Original data', 'Estimation'])
# Preparamos tercer componente
ax3 = f.add_subplot(223)
ax3.set_title('Series tendency')
ax3.plot(forecast['trend'])
# Preparamos cuarto componente
ax4 = f.add_subplot(224)
ax4.set_title('Seasonal yearly component of the series')
ax4.plot(forecast['season_yearly'])

# %% [markdown]
# Nuevamente, nos quedamos con el dataframe con las predicciones, esta vez las de Neural Prophet

# %%
forekast = forecast.copy()
forekast['ds'] = forekast['ds'].dt.year.astype(str)
forekast
# Out:
#       ds             y         yhat1         trend  season_yearly  \
# 0   1970  6.379761e+11  3.235794e+11 -1.075797e+13   1.108155e+13
# 1   1971  7.242669e+11  7.314769e+11 -1.047202e+13   1.120349e+13
# 2   1972  8.739369e+11  1.135460e+12 -1.018606e+13   1.132152e+13
# 3   1973  1.134326e+12  1.037785e+12 -9.917927e+12   1.095571e+13
# 4   1974  1.285878e+12  1.400981e+12 -9.680568e+12   1.108155e+13
# ..   ...           ...           ...           ...            ...
# 50  2020  1.311725e+13  1.566591e+13  4.344391e+12   1.132152e+13
# 51  2021  1.459672e+13  1.568109e+13  4.725379e+12   1.095571e+13
# 52  2022           NaN  1.618687e+13  5.105325e+12   1.108155e+13
# 53  2023           NaN  1.668877e+13  5.485273e+12   1.120349e+13
# 54  2024           NaN  1.718674e+13  5.865219e+12   1.132152e+13
#
#        residual1
# 0   3.143966e+11
# 1  -7.210021e+09
# 2  -2.615236e+11
# 3   9.654064e+10
# 4  -1.151024e+11
# ..           ...
# 50 -2.548661e+12
# 51 -1.084373e+12
# ...

# %%
# Generamos unos intervalos de confianza de +10% y -10% del valor de las predicciones
conf_int_lower = forekast['yhat1']*0.9  # Limite inferior ficticio
conf_int_upper = forekast['yhat1']*1.1  # Limite superior ficticio

# Creamos un DataFrame con los datos de nuestras predicciones y los límites de confianza ficticios anteriormente descritos
df_forekast = pd.DataFrame({'ds': forekast["ds"], 'y': forekast['y'], 'yhat': forekast['yhat1'], 'Lower': conf_int_lower, 'Upper': conf_int_upper})
df_forekast.to_csv("Data/NeuralProphetForecast_limits.csv", index=False)

# %% [markdown]
# Nos guardamos además otras variables de interés

# %%
Eurozona = df[df["Currency"] == "Euro"].drop(columns=["Currency"])
Eurozona = Eurozona.groupby("Year")["GDP"].sum().reset_index() # Eurozona solo con la columna PIB
Eurozona.to_csv("Data/Eurozona.csv", index=False)

# %%
Eurozona = df[df["Currency"] == "Euro"].drop(columns=["Currency"]) # Eurozona con todas las columnas del dataset
Eurozona.to_csv("Data/EurozonaCompleto.csv", index=False)

# %% [markdown]
# # <center><B><FONT COLOR=#FCB714> 4. </FONT> Conclusiones del estudio </FONT></center>

# %% [markdown]
# Ya se han ido desgranando en cada uno de los gráficos o tests de hipótesis algunas de las conclusiones principales, pero vamos a sintetizarlas aquí.
#
# <FONT COLOR=#FCB714> **Conclusiones Globales**:</FONT>
# - La población de Asia y África no muestra signos de que vaya a ralentizarse en el corto plazo, mientras que en el resto de continentes la población permanece prácticamente estancada.
# - Los shocks en el desempleo parece que son cada vez menos pronunciados.
# - Los países con mayor PIBpc tienen un nivel más reducido de desempleo y un mayor índice de desarrollo humano.
# - Los países con mayor PIB tienen unas tasas de crecimiento superiores, al contrario de lo que parece que sugiere la teoría económica, que los países más desarrollados (primer mundo) suelen tener un crecimiento menor que los menos desarrollados (tercer mundo); también, los países con más PIB poseen unas tasas de desempleo menores, que sí suele ser lo común y lo esperable.
# - Europa fue el continente con mayor PIBpc promedio en todo el periodo estudiado, seguido de Norteamérica, pero este promedio podría haberse visto influenciado por datos extremos, como por ejemplo países como Mónaco. Asia y Oceanía tuvieron un promedio similar y, en último lugar, África y Sudamérica.
# - Los datos sugieren que el crecimiento del PIB de todos los continentes está disminuyendo. Esta diferencia se hace más visible comparando los crecimientos de distintas etapas. Europa presenta tanto máximos como mínimos locales en varios momentos del periodo, mientras que Norteamérica parece ser el menos volátil/más estable.
#
# <FONT COLOR=#FCB714> **Conclusiones Internacionales**:</FONT>
# - La Eurozona presenta una evolución del PIB relativamente similar al de Estados Unidos, aunque prácticamente siempre a un nivel inferior. Sin embargo, la Eurozona parece estar estancada desde la crisis de 2008 , por lo que estas diferencias se han pronunciado.
# - Comparando con la otra superpotencia, China, la Eurozona presentó unos niveles superiores de renta, pero debido a su evolución casi exponencial, ha sido recientemente superada por China.
# - En lo que a otras potencias refiere, presenta datos agregados superiores a Japón, Rusia, India o Korea del Sur.
# - Cuando hablamos en términos de PIB per cápita, China prácticamente desaparece de la ecuación, al igual que India o incluso Rusia. La Eurozona presenta datos de PIB per cápita similares a los de Japón, Reino Unido y Korea del Sur, pero aún está lejos de alcanzar EE.UU.
# - Presenta los datos de Consumo público más elevados en función del PIB frente a sus competidores inmediatos, China y EE.UU., lo que sugiere un gran peso del Gobierno en los Estados europeos. Peso que, por los datos de la tendencia, parece que va a seguir aumentando.
# - En contraposición al punto del Consumo público, la Eurozona y EE.UU. están prácticamente a la par en lo que al peso que tiene inversión sobre la economía, con una tendencia preocupantemente decreciente. Destaca el crecimiento casi constante a lo largo de toda la serie del peso de la inversión privada sobre el PIB de China, que desde 2004 ya equivalía aproximadamente al peso en la Eurozona y en EE.UU. conjuntamente.
#
# <FONT COLOR=#FCB714> **Conclusiones Interregionales**:</FONT>
# - Paro: España, Grecia y Montenegro son las regiones con más paro, cuyas tasas triplican las de, en contraposición, Luxemburgo, Austria y Países Bajos.
# - Consumos públicos: Irlanda, Kosovo y Luxemburgo son los países con menor peso del estado en cuanto a lo que consumos públicos refiere mientras que en Francia, Mónaco y Países Bajos casi se duplica esta ratio.
# - IDH: Casi todos los países tienen un IDH de muy alto y los que menor IDH tienen no bajan de 0,8.
# - PIB y Población: Alemania, Francia, Italia, España, Países Bajos y Bélgica componen los mayores componentes económicos y poblacionales de la Zona Euro, suponiendo, todos ellos en conjunto, una porción bastante elevada de todos los sectores económicos.
# - PIB per cápita: Por otro lado, Mónaco, Luxemburgo, Irlanda, San Marino, Países Bajos y Austria encabezan la lista de la riqueza media por persona. Habrá que estudiar qué tan bien se reparte la riqueza en estas regiones.
# - Convergencia: Es complicado hablar de convergencia. Hay países como Mónaco, Luxemburgo y San Marino que se ven aparentemente muy por encima de la media europea, pero puede estar provocado por la poca población que hay en estos lugares, aunque también tenemos el caso de Malta y Montenegro, con apenas 1 millón de personas entre ambos y al fondo de las listas en convergencia. Excluyendo esos países más reducidos, países como Irlanda, Finlandia, Países Bajos, Austria, Bélgica y Alemania están situados por encima del 100%, cuando Francia, Italia, España, Portugal y Grecia, en la región geográfica de los denominados como "PIGS" (Portugal, Italy, Greece, Spain), están por debajo de la media. Estas diferencias se deben probablemente a un grandísimo número de casuísticas sociales, políticas, históricas, económicas, geográficas y culturales muy diversas que darían para un estudio propio. Sin embargo, los datos parecen sugerir que con los años estas diferencias se están reduciendo, muy lentamente.
#
#
# <FONT COLOR=#FCB714> **Final**:</FONT><br>
# <B><br>En general, la Eurozona todavía es una aglomeración de países con grandes diferencias entre sus extremos. Sería interesante plantear y estudiar la cuestión de a qué países les ha resultado útil o beneficiosa la anexión a la Unión y a qué países no les ha ido tan bien.

# %% [markdown]
# # <center><B><FONT COLOR=#FCB714> 5. </FONT> Fuentes y Referencias </FONT></center>

# %% [markdown]
# Los datos originales de [Global Economy Indicators](https://www.kaggle.com/datasets/prasad22/global-economy-indicators/data) fueron obtenidos en Kaggle
#
# Códigos [ISIC](https://ilostat.ilo.org/methods/concepts-and-definitions/classification-economic-activities/) para la categorización de las actividades económicas
#
# Wikipedia en [español](https://es.wikipedia.org/wiki/Anexo:Países_por_índice_de_desarrollo_humano) y en [inglés](https://en.wikipedia.org/wiki/List_of_countries_by_Human_Development_Index) con los datos del IDH
#
# Enlace a la web del [Banco Mundial](https://liveprod.worldbank.org/en/indicator/sl-uem-zs#data-table-section) de donde se obtuvieron los datos del desempleo
#
# GitHub de donde se descargó la librería [ffmpeg](https://github.com/BtbN/FFmpeg-Builds/releases) para la creación de gráficos animados
#
# Enlaces a [Statista](https://es.statista.com/estadisticas/600201/crecimiento-del-pib-en-la-ue-y-la-zona-euro/) y el [Banco Mundial](https://datos.bancomundial.org/indicador/NY.GDP.MKTP.CD?locations=XC) donde se pueden encontrar datos sobre el PIB de la Eurozona del año 2022 en adelante
#
# GIF de la portada y del Readme obtenidos del siguiente [enlace](https://www.axios.com/2019/10/14/global-indicators-lowest-since-2016-report)
#
# Los demás GIFs fueron obtenidos en internet buscando palabras clave

# %% [markdown]
# # <center><B><FONT COLOR=#FCB714> ¡Gracias por ver! </FONT></center>
